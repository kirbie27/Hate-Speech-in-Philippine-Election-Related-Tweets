# %%
#import necessary libraries
import pandas as pd
import csv
import re
import validators
import emoji
import unidecode
import nltk
import pickle
nltk.download('stopwords')
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kirby
# [nltk_data]     Wenceslao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Extraction of Filipino Tweets
#Refers to opening the raw data containing the Filipino Tweets
#into the python program

data_path = "data.csv"
#using pandas
df = pd.read_csv(data_path)
df
# Out:
#                                            Tweet Content Sentiment     Label
# 0      Ayuda para sa lahat ni Aling Leni Robredo\nA)\...  Negative      Hate
# 1      FUTURE PUPPET NG MGA OLIGARCHS AT DRUGLORD! Le...  Negative      Hate
# 2      Sino ngayon ang tanso? #votebetterin2022\n htt...  Negative      Hate
# 3      A day after Leni Robredo painted the town pink...  Negative      Hate
# 4      Former senator Antonio Trillanes IV on Friday ...  Negative      Hate
# ...                                                  ...       ...       ...
# 19007  Pakiusap 'wag po natin sayangin ang nag-iisang...  Positive  Non-hate
# 19008  One Big Fight! Atin na 'to!\nhttps://t.co/jBy4...  Positive  Non-hate
# 19009  tears  of  a  true  leader ,  she's  Leni  Rob...  Positive  Non-hate
# 19010  Handa na akong magiging susunod na Presidente ...  Positive  Non-hate
# 19011  If you want a better future for our country, p...  Positive  Non-hate
#
# [19012 rows x 3 columns]

# %%
df.Label.value_counts()
# Out:
# Non-hate    16446
# Hate         2566
# Name: Label, dtype: int64

# %%
df.Sentiment.value_counts()
# Out:
# Neutral     10284
# Positive     6162
# Negative     2566
# Name: Sentiment, dtype: int64

# %%
groupedby_sentiment = df.groupby(df.Sentiment)
df_positive = groupedby_sentiment.get_group("Positive")
df_positive
# Out:
#                                            Tweet Content Sentiment     Label
# 12850  LOOK: Beautiful Ladies inside and out Janella ...  Positive  Non-hate
# 12851  Eto ang totoo\nSa lahat ng kandidato\nSa pagka...  Positive  Non-hate
# 12852  how do people even have the audacity not to re...  Positive  Non-hate
# 12853            @ABSCBNNews Go,,,go,,,pres,Leni robredo  Positive  Non-hate
# 12854  Malungkot sa pagpanaw ng CHR chair Chito Gasco...  Positive  Non-hate
# ...                                                  ...       ...       ...
# 19007  Pakiusap 'wag po natin sayangin ang nag-iisang...  Positive  Non-hate
# 19008  One Big Fight! Atin na 'to!\nhttps://t.co/jBy4...  Positive  Non-hate
# 19009  tears  of  a  true  leader ,  she's  Leni  Rob...  Positive  Non-hate
# 19010  Handa na akong magiging susunod na Presidente ...  Positive  Non-hate
# 19011  If you want a better future for our country, p...  Positive  Non-hate
#
# [6162 rows x 3 columns]

# %%
df_negative = groupedby_sentiment.get_group("Negative")
df_negative
# Out:
#                                           Tweet Content Sentiment Label
# 0     Ayuda para sa lahat ni Aling Leni Robredo\nA)\...  Negative  Hate
# 1     FUTURE PUPPET NG MGA OLIGARCHS AT DRUGLORD! Le...  Negative  Hate
# 2     Sino ngayon ang tanso? #votebetterin2022\n htt...  Negative  Hate
# 3     A day after Leni Robredo painted the town pink...  Negative  Hate
# 4     Former senator Antonio Trillanes IV on Friday ...  Negative  Hate
# ...                                                 ...       ...   ...
# 2561  putanginv sabi ng kapatid ko kung wala daw yun...  Negative  Hate
# 2562  @Mira_cleketuy the philippine national electio...  Negative  Hate
# 2812  Hay grabe ka ISKO MORENO DOMAGOSO,\nWag na wag...  Negative  Hate
# 2906  Baka lang may mag-isip na porque I'm championi...  Negative  Hate
# 3024  Bongbong Marcos has spoken, kween tingz #BBM #...  Negative  Hate
#
# [2566 rows x 3 columns]

# %%
df_neutral = groupedby_sentiment.get_group("Neutral")
df_neutral
# Out:
#                                            Tweet Content Sentiment     Label
# 2563   PLS PLS PLS DON'T CONNECT ALL COLOR PINK YOU S...   Neutral  Non-hate
# 2564   @dearmistermuse Bongbong Marcos, Isko Moreno, ...   Neutral  Non-hate
# 2565   Supporters ni VP Leni Robredo, nag motorcade s...   Neutral  Non-hate
# 2566   Kung hindi kasalanan ng anak ang mga nagawa ng...   Neutral  Non-hate
# 2567   Verrrry interesting that @IskoMoreno No. 3 in ...   Neutral  Non-hate
# ...                                                  ...       ...       ...
# 12845  Ang Presidente \n        LENI ROBREDO\nBise Pr...   Neutral  Non-hate
# 12846  May 07, 2022 Trending: In recent weeks, legion...   Neutral  Non-hate
# 12847  Ang Presidente-Leni Robredo\nBise Presidente-K...   Neutral  Non-hate
# 12848  Ang presidente LENI ROBREDO Bise presidente KI...   Neutral  Non-hate
# 12849  for the last time, number 10 sa balota, Leni R...   Neutral  Non-hate
#
# [10284 rows x 3 columns]

# %%
#binary hate non-hate
df_hate = df_negative.sample(n = 2560)

df_positive = df_positive.sample(n = 2560)
df_neutral = df_neutral.sample(n = 2560)

df_nonhate = df_positive.append(df_neutral)

df_dataset = df_hate.append(df_nonhate)

# %%
df_dataset.to_csv('dataset.csv', index=False)
df_dataset
# Out:
#                                            Tweet Content Sentiment     Label
# 1539   Dictator's son on the cusp of power in the #Ph...  Negative      Hate
# 534    Kung ang definition ni BongBong Marcos sa isan...  Negative      Hate
# 2033   Leni Robredo is not being subjected by her opp...  Negative      Hate
# 338    @imstillsour Tuwang tuwa sila sa Pink hahaha.....  Negative      Hate
# 1439   Kapag hindi si VP Leni Robredo ang iboboto mo ...  Negative      Hate
# ...                                                  ...       ...       ...
# 12524   VP LENI ROBREDO FOR 2022 https://t.co/2ahSefgmST   Neutral  Non-hate
# 9240   @alt_ego143 @rapplerdotcom @ramboreports hindi...   Neutral  Non-hate
# 8374   I can't vote yet, but my president is Leni Rob...   Neutral  Non-hate
# 10308  Anyways President Leni Robredo #SaveLegendsOfT...   Neutral  Non-hate
# 3093   Kung ayaw nyo d wag nyo iboto.Napaka simple.. ...   Neutral  Non-hate
#
# [7680 rows x 3 columns]

# %%
dataset = "dataset.csv"

# %%
#using csv reader only

file = open(dataset, encoding='utf-8')

csv_reader = csv.reader(file)

#skipping the header
header = next(csv_reader)

tweets = []
labels = []
sentiments = []
for row in csv_reader:
    #row_dict = {'Text': row[0].strip().replace("\n"," "), 'Label': row[2]}
    tweets.append(row[0].strip().replace("\n"," "))
    sentiments.append(row[1])
    labels.append(row[2])
    
for i in range(10):
    print('Text: ', tweets[i], "\n\nLabel: ", sentiments[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# %%
#Data De-Identification
#Refers to the removal of the mentions in each tweet
#source regex https://stackoverflow.com/questions/2304632/regex-for-twitter-username


#data
tweets_de_identified = []

#insert process code
for tweet in tweets:
    output = ""
    sentence = tweet.split(" ")
    for part in sentence:
        if not re.match(r"(^|[^@\w])@(\w{1,15})\b", part):
            if len(output) == 0:
                output = f"{part}"
            else:
                output = f"{output} {part}"

    tweets_de_identified.append(output)

for i in range(10):
    print('Text: ', tweets_de_identified[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  Dictator's son on the cusp of power in the #Philippines #marcos https://t.co/5wbFYVWlG4
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kung ang definition ni BongBong Marcos sa isang terorista ay isang armadong grupo na nananakit, nanunupil ng civilian o teenager na NON COMBATANT, pinapatunayan lang na ang PNP-AFP ay terorista.  EJK sa Drug War at Martial Law mismo ang ebidensya.  #ManggagawaVSMagnanakaw
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Leni Robredo is not being subjected by her opponents to gender attact but her intelligence and capacity to lead are put into question... we do not want a puppet president... https://t.co/hzn3LiQ5uJ
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Tuwang tuwa sila sa Pink hahaha..hindi nila alam Pink color is sign for Bongbong Marcos..kasi favorite nya isuot pink...ambilis ni Leni mag grab ng color kasi nakita nila langit nag Pink hahaha😅😂😂
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kapag hindi si VP Leni Robredo ang iboboto mo sa May 9 2022!! 6 YEARS KANG MAMALASIN...
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  kakampinks sleeping soundly tonight knowing that leni robredo did well in tonight’s debate. pero yung iba, double time sa paghahanap ng mali. 😂 hirap talaga pag wala ka mapagmalaki sa kandidato mo sa iba ka nalang titingin. #10RobredoPresident #IpanaloNa10To
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  leni robredo daw potanginaAAAAUSASASSASA
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Son of a Dictator | The rise of FERDINAND MARCOS JNR - This week on FOREIGN CORRESPONDENT   Read More -&gt; https://t.co/FNivaeF42j https://t.co/HWGtOLR2e5
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Fascinating read 👇🏼  Why Bongbong Marcos, a Philippine dictator’s Son, leads the race for the presidency https://t.co/U93PcvdMYB
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Lol! Walang kwenta yang pagmamagaling nyo. Ano ang ginawa nyo for 6 years? Di ba bullying din? Ngayon sasabihin nyo tinuturuan ni joma sison si leni robredo?
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#Uniform Resource Locator Removal
#The removal of urls/links such as media included in a tweet
#uses validators import 
#does not include strings that is not a hyper link which means that it will only remove urls that start with http or https,
#as those types of urls are clickable on tweets

#data
tweets_url_removed = []

#insert process code


for tweet in tweets_de_identified:
    output = ""
    sentence = tweet.split(" ")
    for part in sentence:
        valid = validators.url(part)

        if (not valid == True):
            if len(output) == 0:
                output = f"{part}"
            else:
                output = f"{output} {part}"
    tweets_url_removed.append(output)

#output
for i in range(10):
    print('Text: ', tweets_url_removed[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  Dictator's son on the cusp of power in the #Philippines #marcos
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kung ang definition ni BongBong Marcos sa isang terorista ay isang armadong grupo na nananakit, nanunupil ng civilian o teenager na NON COMBATANT, pinapatunayan lang na ang PNP-AFP ay terorista.  EJK sa Drug War at Martial Law mismo ang ebidensya.  #ManggagawaVSMagnanakaw
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Leni Robredo is not being subjected by her opponents to gender attact but her intelligence and capacity to lead are put into question... we do not want a puppet president...
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Tuwang tuwa sila sa Pink hahaha..hindi nila alam Pink color is sign for Bongbong Marcos..kasi favorite nya isuot pink...ambilis ni Leni mag grab ng color kasi nakita nila langit nag Pink hahaha😅😂😂
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kapag hindi si VP Leni Robredo ang iboboto mo sa May 9 2022!! 6 YEARS KANG MAMALASIN...
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  kakampinks sleeping soundly tonight knowing that leni robredo did well in tonight’s debate. pero yung iba, double time sa paghahanap ng mali. 😂 hirap talaga pag wala ka mapagmalaki sa kandidato mo sa iba ka nalang titingin. #10RobredoPresident #IpanaloNa10To
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  leni robredo daw potanginaAAAAUSASASSASA
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Son of a Dictator | The rise of FERDINAND MARCOS JNR - This week on FOREIGN CORRESPONDENT   Read More -&gt;
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Fascinating read 👇🏼  Why Bongbong Marcos, a Philippine dictator’s Son, leads the race for the presidency
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Lol! Walang kwenta yang pagmamagaling nyo. Ano ang ginawa nyo for 6 years? Di ba bullying din? Ngayon sasabihin nyo tinuturuan ni joma sison si leni robredo?
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#Special Character Processing #Kirby
#Refers to the removal of special characters in a tweet that
#are standalone and not used as part of a word

#data
tweets_specialcharacters_removed = []

#insert process code

#remove emojis
#https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python
        
#remove special characters not part of a word 
#https://stackoverflow.com/questions/28860440/check-when-string-contains-only-special-characters-in-python


for tweet in tweets_url_removed:
    emoji_removed = emoji.replace_emoji(tweet, replace="[emoji]")
    sentence = emoji_removed.split(" ")
    output = ""       

    for part in sentence:
        if not (re.match(r"^[_\W]+$", part) or "[emoji]" in part):
            if len(output) == 0:
                output = f"{part}"
            else:
                output = f"{output} {part}"
    
    tweets_specialcharacters_removed.append(output)

#output
for i in range(10):
    print('Text: ', tweets_specialcharacters_removed[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  Dictator's son on the cusp of power in the #Philippines #marcos
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kung ang definition ni BongBong Marcos sa isang terorista ay isang armadong grupo na nananakit, nanunupil ng civilian o teenager na NON COMBATANT, pinapatunayan lang na ang PNP-AFP ay terorista.  EJK sa Drug War at Martial Law mismo ang ebidensya.  #ManggagawaVSMagnanakaw
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Leni Robredo is not being subjected by her opponents to gender attact but her intelligence and capacity to lead are put into question... we do not want a puppet president...
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Tuwang tuwa sila sa Pink hahaha..hindi nila alam Pink color is sign for Bongbong Marcos..kasi favorite nya isuot pink...ambilis ni Leni mag grab ng color kasi nakita nila langit nag Pink
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Kapag hindi si VP Leni Robredo ang iboboto mo sa May 9 2022!! 6 YEARS KANG MAMALASIN...
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  kakampinks sleeping soundly tonight knowing that leni robredo did well in tonight’s debate. pero yung iba, double time sa paghahanap ng mali. hirap talaga pag wala ka mapagmalaki sa kandidato mo sa iba ka nalang titingin. #10RobredoPresident #IpanaloNa10To
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  leni robredo daw potanginaAAAAUSASASSASA
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Son of a Dictator The rise of FERDINAND MARCOS JNR This week on FOREIGN CORRESPONDENT   Read More -&gt;
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Fascinating read  Why Bongbong Marcos, a Philippine dictator’s Son, leads the race for the presidency
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  Lol! Walang kwenta yang pagmamagaling nyo. Ano ang ginawa nyo for 6 years? Di ba bullying din? Ngayon sasabihin nyo tinuturuan ni joma sison si leni robredo?
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
filipino_stopwords = set(
    """
akin
aking
ako
alin
am
amin
aming
ang
ano
anumang
apat
at
atin
ating
ay
bababa
bago
bakit
bawat
bilang
dahil
dalawa
dapat
din
dito
doon
gagawin
gayunman
ginagawa
ginawa
ginawang
gumawa
gusto
habang
hanggang
hindi
huwag
iba
ibaba
ibabaw
ibig
ikaw
ilagay
ilalim
ilan
inyong
isa
isang
itaas
ito
iyo
iyon
iyong
ka
kahit
kailangan
kailanman
kami
kanila
kanilang
kanino
kanya
kanyang
kapag
kapwa
karamihan
katiyakan
katulad
kaya
kaysa
ko
kong
kulang
kumuha
kung
laban
lahat
lamang
likod
lima
maaari
maaaring
maging
mahusay
makita
marami
marapat
masyado
may
mayroon
mga
minsan
mismo
mula
muli
na
nabanggit
naging
nagkaroon
nais
nakita
namin
napaka
narito
nasaan
ng
ngayon
ni
nila
nilang
nito
niya
niyang
noon
o
pa
paano
pababa
paggawa
pagitan
pagkakaroon
pagkatapos
palabas
pamamagitan
panahon
pangalawa
para
paraan
pareho
pataas
pero
pumunta
pumupunta
sa
saan
sabi
sabihin
sarili
sila
sino
siya
tatlo
tayo
tulad
tungkol
una
walang
""".split()
)

# %%
#Normalization #Kirby
#Further cleaning of each tweet and removal of the topics
#which are the 10 Philippine National Candidates



#normalization process
#lowercase the tweet
#remove diacritics, numerics, english or filipino stopwords,
#and candidate names


#data
tweets_normalized = []

#test
input = "LOWERCASE THIS dont , remove this name leni robredo, ñññ and bongbong, ?! 123 14"


#insert process code

#declare stopwords and candidate names
from nltk.corpus import stopwords
english_stopwords = stopwords.words('english')
search = "leni robredo bongbong marcos isko moreno domagoso manny pacman pacquiao ping lacson ernie abella leody de guzman norberto gonzales jose montemayor jr faisal mangondato"
candidatelist = search.split(" ")

for tweet in tweets_url_removed:
    
    #lowercase the text
    lowercased_input = tweet.lower()

    #remove diacritics
    diacritics_removed = unidecode.unidecode(lowercased_input)

    sentence = diacritics_removed.split(" ")
    output = ""
    
    #remove numerical, stopwords, and candidate names
    for part in sentence:
        part = re.sub("[^A-Za-z ]+$", "", part)
        part = re.sub("^[^A-Za-z #]+", "", part)
        if not (len(part) <= 1 or re.match(r"[^a-zA-Z#]", part) or part in english_stopwords or part in filipino_stopwords or any(part in x for x in candidatelist)):     
            if len(output) == 0:
                output = f"{part}"
            else:
                output = f"{output} {part}" 
                
    tweets_normalized.append(output)

#output
for i in range(10):
    print('Text: ', tweets_normalized[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  dictator's cusp power #philippines #marcos
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  definition terorista armadong grupo nananakit nanunupil civilian teenager non combatant pinapatunayan lang pnp-afp terorista ejk drug war martial law ebidensya #manggagawavsmagnanakaw
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  subjected opponents gender attact intelligence capacity lead put question want puppet president
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  tuwang tuwa pink hahaha..hindi alam pink color sign marcos..kasi favorite nya isuot pink...ambilis grab color kasi langit nag pink hahaha
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  si vp iboboto years kang mamalasin
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  kakampinks sleeping soundly tonight knowing well tonight's debate yung double time paghahanap mali hirap talaga pag wala mapagmalaki kandidato nalang titingin #10robredopresident #ipanalona10to
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  daw potanginaaaaausasassasa
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  dictator rise ferdinand jnr week foreign correspondent read gt
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  fascinating read philippine dictator's leads race presidency
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  lol kwenta yang pagmamagaling nyo nyo years di ba bullying sasabihin nyo tinuturuan joma sison si
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#Hashtag Processing
#Removal of the hashtags contained in a tweet

#data
tweets_hashtags_removed = []


#insert process code

for tweet in tweets_normalized:
    output = ""
    sentence = tweet.split(" ")

    for part in sentence:
        if not re.match(r"#(\w+)", part):
            if len(output) == 0:
                output = f"{part}"
            else:
                output = f"{output} {part}"
    tweets_hashtags_removed.append(output)

#output
for i in range(10):
    print('Text: ', tweets_hashtags_removed[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  dictator's cusp power
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  definition terorista armadong grupo nananakit nanunupil civilian teenager non combatant pinapatunayan lang pnp-afp terorista ejk drug war martial law ebidensya
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  subjected opponents gender attact intelligence capacity lead put question want puppet president
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  tuwang tuwa pink hahaha..hindi alam pink color sign marcos..kasi favorite nya isuot pink...ambilis grab color kasi langit nag pink hahaha
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  si vp iboboto years kang mamalasin
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  kakampinks sleeping soundly tonight knowing well tonight's debate yung double time paghahanap mali hirap talaga pag wala mapagmalaki kandidato nalang titingin
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  daw potanginaaaaausasassasa
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  dictator rise ferdinand jnr week foreign correspondent read gt
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  fascinating read philippine dictator's leads race presidency
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  lol kwenta yang pagmamagaling nyo nyo years di ba bullying sasabihin nyo tinuturuan joma sison si
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#Tokenization
#Segmentation of phrases into words

#data
tweets_tokenized = []

#insert process code
from nltk.tokenize import WhitespaceTokenizer

tokenizer = WhitespaceTokenizer()

for tweet in tweets_hashtags_removed:
    output = tokenizer.tokenize(tweet)
    tweets_tokenized.append(output)

#output
for i in range(125):
    print('Text: ', tweets_tokenized[i], "\n\nLabel: ", labels[i],"\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# Text:  ["dictator's", 'cusp', 'power']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['definition', 'terorista', 'armadong', 'grupo', 'nananakit', 'nanunupil', 'civilian', 'teenager', 'non', 'combatant', 'pinapatunayan', 'lang', 'pnp-afp', 'terorista', 'ejk', 'drug', 'war', 'martial', 'law', 'ebidensya']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['subjected', 'opponents', 'gender', 'attact', 'intelligence', 'capacity', 'lead', 'put', 'question', 'want', 'puppet', 'president']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['tuwang', 'tuwa', 'pink', 'hahaha..hindi', 'alam', 'pink', 'color', 'sign', 'marcos..kasi', 'favorite', 'nya', 'isuot', 'pink...ambilis', 'grab', 'color', 'kasi', 'langit', 'nag', 'pink', 'hahaha']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['si', 'vp', 'iboboto', 'years', 'kang', 'mamalasin']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  

#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['heaviest', 'burden', "that's", 'dragging', "marcos's", 'march', 'malacanang', 'truth', 'glorious', 'truth', 'matter', 'look', 'personally', 'academically', 'professionally', 'politically', 'morally', 'match']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['call', 'influencer', 'pati', 'pag', 'sisimba', 'titirahin', 'niyo', 'jusko', 'kiko', 'pangilinan', 'condemn', 'kind', 'attitude', 'artists', 'influencer', 'sumusuporta', 'sainyo', 'oo', 'nakakadismaya', 'talaga', 'pag', 'ganito', 'nakakabastos']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['mag-iingay', 'naman', 'itong', 'supporter', 'ipagtanggol', 'si', 'pagiging', 'absent', 'debate', 'kayo', 'proxy']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['ung', 'supporters', 'wag', 'niyo', 'po', 'pag', 'aksayahan', 'boto', 'kesa', 'knya', 'ibigay', 'niyo', 'lang', 'po', 'boto', 'niyo', 'kay', 'vp', 'kiko', 'pangilinan']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['volunteers', 'allegedly', 'blocked', 'campaigning', 'samar', 'town', 'via', 'bbm', 'martal', 'law', 'bbm', 'golden', 'age', 'starting', 'bbm', 'bobo,liar,theif,tax', 'cheat', 'atty,exp', 'ldr,honest,pays', 'tax,not', 'liar,not', 'theif,gold', 'heart', 'vot', 'pres']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['think', 'yung', 'ki', 'bobong', 'narcos', 'money', 'time', 'election', 'swap', 'th', 'president', 'kiko', 'pangilinan', 'vote...hmmm', 'make', 'sense', 'po', 'kakampink']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['philippines', 'former', 'dictator', 'competes', 'anti-populist', 'presidential', 'election']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['family', 'people', 'betrayed', 'country', 'profited', 'ill-gotten', 'wealth', 'seeking', 'elective', 'office', 'paanong', 'past', 'past', 'capitalizes', "father's", 'name', 'achievements', 'trapo']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['fact', 'nothing', 'without', "father's", 'name', 'well', "he's", 'nothing', 'nobody']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['wow', 'smni', 'audience', 'heckling', 'open', 'peace', 'talks', 'wew', "that's", 'fascist', 'echo', 'chamber', 'saw', 'one']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['si', 'kulelat', 'according', 'table', "he's", 'much', 'better', 'absentee', 'issue', 'amongst', 'issues']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['anim', 'taong', 'tiniis', 'bayan', 'style-kantong', 'thuggery', 'duterte', 'june', 'sisipain', 'malacanang', 'july', 'mag-iiba', 'socio-political', 'atmosphere', 'intellectual-cultural', 'horizon', 'pilipinas', 'bagong', 'gobyerno', 'vp']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['marcosjr', 'duwag', 'ayaw', 'umattend', 'debate', 'kayang', 'ipagtanggol', 'pamilya', 'nya', 'pamilya', 'nya', 'nga', 'nya', 'kayang', 'ipagtanggol', 'panindigan', 'sambayanang', 'pilipino', 'gising', 'pilipinas', 'win']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['miss', 'anong', 'pinagsasabi', 'mong', 'ina', 'kapatid', 'si']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['young', 'ones', 'know', "dictator's", 'dark', 'past', 'whitewashed']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['idiots', 'keep', 'comparing', "bbm's", 'performance', "robredo's", 'tanong', 'lang', 'ha', 'alam', 'niyo', 'ba', 'difference', 'role', 'senator', 'role', 'vice', 'president', 'malacanang', 'narrow-minded', 'idiots', 'nakikisabay', 'uso', 'pwe']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['lawrd', 'needs', 'reality', 'check', 'tired', 'hearing', 'pure', 'bs', 'politicians', 'detached', 'reality']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['violy', 'violy', 'oh', 'violeta', 'baka', 'payuhan', 'si', 'bobong', 'este', 'tantanan', 'pagiging', 'absent', 'alamano', 'kasi']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['summary', "robredo's", 'platform', 'bawal']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['wtf', 'ata', 'unang', 'makakareview', 'movie', 'letterboxd']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['athletes', 'supports', 'group', 'desparate', 'desire', 'win', 'thus', 'wanted', 'everything', 'identified', 'i,e', 'dogs', 'cats', 'fish', 'doctors', 'artist', 'ect', 'ect', 'ect', 'tsk', 'tsk', 'tsk']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['dami', 'good', 'accomplishment', 'course', 'list', 'kang', 'complain', 'sumipot', 'kandidato', 'debate', 'naduwag']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['late', 'dictator', 'ferdinand', 'poised', 'win', 'philippines', 'election']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['is/ko', 'mo/reno', 'attacking', 'see', 'true', 'colors', 'shining']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Text:  ['proven', 'true', 'yet', 'need', 'attend', 'debates', 'either']
#
# Label:  Hate
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
print(len(tweets_tokenized), len(labels))
# Out:
# 7680 7680

# %%
#x = tweets_tokenized, y = labels
x = tweets_tokenized
y = sentiments

# %%
#Data Splitting and Saving

#70-30 split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3)

#Saving data to be used on other files
x_train_file = open('7030/x_train.pkl', 'wb')
pickle.dump(x_train,x_train_file)
x_train_file.close()

x_test_file = open('7030/x_test.pkl', 'wb')
pickle.dump(x_test,x_test_file)
x_test_file.close()

y_train_file = open('7030/y_train.pkl', 'wb')
pickle.dump(y_train,y_train_file)
y_train_file.close()

y_test_file = open('7030/y_test.pkl', 'wb')
pickle.dump(y_test,y_test_file)
y_test_file.close()

tweet_collection_file = open('7030/tweet_collection.pkl', 'wb')
pickle.dump(tweets_tokenized,tweet_collection_file)
tweet_collection_file.close()

# %%
#Data Splitting and Saving

#80-20 split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

#Saving data to be used on other files
x_train_file = open('8020/x_train.pkl', 'wb')
pickle.dump(x_train,x_train_file)
x_train_file.close()

x_test_file = open('8020/x_test.pkl', 'wb')
pickle.dump(x_test,x_test_file)
x_test_file.close()

y_train_file = open('8020/y_train.pkl', 'wb')
pickle.dump(y_train,y_train_file)
y_train_file.close()

y_test_file = open('8020/y_test.pkl', 'wb')
pickle.dump(y_test,y_test_file)
y_test_file.close()

tweet_collection_file = open('8020/tweet_collection.pkl', 'wb')
pickle.dump(tweets_tokenized,tweet_collection_file)
tweet_collection_file.close()

# %%
#Data Splitting and Saving

#90-10 split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.9, test_size=0.1)

#Saving data to be used on other files
x_train_file = open('9010/x_train.pkl', 'wb')
pickle.dump(x_train,x_train_file)
x_train_file.close()

x_test_file = open('9010/x_test.pkl', 'wb')
pickle.dump(x_test,x_test_file)
x_test_file.close()

y_train_file = open('9010/y_train.pkl', 'wb')
pickle.dump(y_train,y_train_file)
y_train_file.close()

y_test_file = open('9010/y_test.pkl', 'wb')
pickle.dump(y_test,y_test_file)
y_test_file.close()

tweet_collection_file = open('9010/tweet_collection.pkl', 'wb')
pickle.dump(tweets_tokenized,tweet_collection_file)
tweet_collection_file.close()
