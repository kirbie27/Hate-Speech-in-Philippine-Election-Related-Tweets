# %%
#import necessary libraries
import pandas as pd
import csv
import re
import validators
import emoji
import unidecode
import nltk
import pickle
nltk.download('stopwords')
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.tokenize import WhitespaceTokenizer
from itertools import chain
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import keras
from keras.preprocessing import sequence
import tensorflow as tf
from keras import Input
from keras import optimizers
from keras import backend as K
import torch
from keras import regularizers
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_blobs
from keras.models import Sequential
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.models import load_model
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectPercentile, f_classif

import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import np_utils
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from itertools import chain

from tqdm import tqdm
from gensim.models import fasttext
from gensim.test.utils import datapath
import os, re, csv, math, codecs, pickle, nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kirby
# [nltk_data]     Wenceslao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Load test and testresutls   

with open('x_test.pkl', 'rb') as file:
    x_test = pickle.load(file)
    
with open('y_test.pkl', 'rb') as file:
    y_test = pickle.load(file)
    
with open('fastTextCNN_test_results.pkl', 'rb') as file:
    fastTextCNN_test_results = pickle.load(file) 
    
with open('TFIDFFFNN_test_results.pkl', 'rb') as file:
    TFIDFFFNN_test_results = pickle.load(file)  
    
#Convert Labels from Strings to categorical Integers {Non-Hate = 1, Hate = 0}


df_ytest = pd.DataFrame(y_test, columns = ['Label'])

fastTextCNN_test_results.columns = ['Tokens', 'Label', 'Prediction']
fastTextCNN_test_results['Label'] = fastTextCNN_test_results['Label'].str.get(0)
fastTextCNN_test_results['Prediction'] = fastTextCNN_test_results['Prediction'].str.get(0)

fastTextCNN_tweets_joined = []

for i in range(len(fastTextCNN_test_results.Tokens.values)):
    tweet = " ".join(fastTextCNN_test_results.Tokens.values[i])
    fastTextCNN_tweets_joined.append(tweet)
    
fastTextCNN_test_results.insert(0, "Tweet", fastTextCNN_tweets_joined, True)


TFIDFFFNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

tfidfffnn_tweets_joined = []
for i in range(len(TFIDFFFNN_test_results.Tokens.values)):
    tweet = " ".join(TFIDFFFNN_test_results.Tokens.values[i])
    tfidfffnn_tweets_joined.append(tweet)
    
TFIDFFFNN_test_results.insert(0, "Tweet", tfidfffnn_tweets_joined, True)
#TFIDFFFNN_test_results['Label'] = TFIDFFFNN_test_results['Label'].str.get(0)
#TFIDFFFNN_test_results['Prediction'] = TFIDFFFNN_test_results['Prediction'].str.get(0)
#flatten training set for fitting on tfidf
#x_train_fit = list(chain.from_iterable(x_train))

mapping = {'Non-hate': 0, 'Hate': 1}
mapping_reverse = {0: 'Non-hate', 1: 'Hate'}
fastTextCNN_test_results = fastTextCNN_test_results.replace({'Label': mapping_reverse})
TFIDFFFNN_test_results = TFIDFFFNN_test_results.replace({'Label': mapping_reverse})
df_ytest = df_ytest.replace({'Label': mapping})


train_y = df_ytrain['Label'].tolist()
test_y = df_ytest['Label'].tolist()

np_train_y = np.asarray(train_y)
np_test_y = np.asarray(test_y)
    
#feed train set on vectorizer 
#tokenizer = Tokenizer(num_words=100000, char_level=False)
#tokenizer.fit_on_texts(x_train_fit)

# %%
def dummy_fun(doc):
    return doc

def get_keywords(data,filename):
    print(filename)
    tfidf = TfidfVectorizer(
        analyzer='word',
        tokenizer=dummy_fun,
        preprocessor=dummy_fun,
        token_pattern=None)  

    #fit text to tfidf
    tfidf.fit_transform(data)


    fasttext_dict = list(zip(tfidf.get_feature_names(), tfidf.idf_))
    fasttext_df = pd.DataFrame(fasttext_dict, columns = ['Token', 'TFIDF_Value'])
    fasttextresults_label_sorted = fasttext_df.sort_values(by=['TFIDF_Value'], ascending=False)
    fasttextresults_label_sorted.to_csv(filename, index=False)
    
    return fasttextresults_label_sorted

# %%
TFIDFFFNN_test_results.to_csv('TFIDFFFNN_test_results.csv', index=False)
TFIDFFFNN_test_results
# Out:
#                                                   Tweet  \
# 0       future president iktr gaga stans spitting facts
# 1     tulungan nating manalo sara duterte darating e...
# 2                                ayan spoon feed sau ha
# 3     nagtataka okay lang suportahan communist group...
# 4     obviously attend smni debate owner network sum...
# ...                                                 ...
# 1531  makakalimutan itong h2h grand rally napuntahan...
# 1532       daughters girls anong klaseng katangahan yan
# 1533  even signature figure liberal party projects p...
# 1534                                     best job woman
# 1535             apologist hahahaa yung hubby si friend
#
#                                                  Tokens     Label  Prediction
# 0     [future, president, iktr, gaga, stans, spittin...  Non-hate    0.953089
# 1     [tulungan, nating, manalo, sara, duterte, dara...  Non-hate    0.999718
# 2                          [ayan, spoon, feed, sau, ha]      Hate    0.997534
# 3     [nagtataka, okay, lang, suportahan, communist,...      Hate    0.999990
# 4     [obviously, attend, smni, debate, owner, netwo...  Non-hate    0.985766
# ...                                                 ...       ...         ...
# 1531  [makakalimutan, itong, h2h, grand, rally, napu...  Non-hate    0.999829
# 1532  [daughters, girls, anong, klaseng, katangahan,...      Hate    0.999839
# 1533  [even, signature, figure, liberal, party, proj...      Hate    0.933070
# 1534                                 [best, job, woman]  Non-hate    0.999997
# 1535      [apologist, hahahaa, yung, hubby, si, friend]      Hate    0.962922
#
# [1536 rows x 4 columns]

# %%
groupedby_ffnn_label = TFIDFFFNN_test_results.groupby(TFIDFFFNN_test_results.Label)

#group by label
ffnn_nonhate = groupedby_ffnn_label.get_group("Non-hate")
ffnn_hate = groupedby_ffnn_label.get_group("Hate")

# %%
#tfidf highest keywords ffnn hate
get_keywords(ffnn_hate.Tokens.values,'TFIDFFFNN_hate_keywords.csv').head(20)
# Out:
# TFIDFFFNN_hate_keywords.csv
#              Token  TFIDF_Value
# 0          aabutin     6.995208
# 2570        nahiya     6.995208
# 2557   nagsasalita     6.995208
# 2559     nagsimula     6.995208
# 2561       nagtago     6.995208
# 2562     nagtataka     6.995208
# 2563  nagtatrabaho     6.995208
# 2564  nagtotorture     6.995208
# 2565    nagtutulak     6.995208
# 2566       nahagip     6.995208
# 2567      nahehelo     6.995208
# 2568      nahihiya     6.995208
# 2569      nahimlay     6.995208
# 2571      naidulot     6.995208
# 2526    nagbo-bomb     6.995208
# 2572       naiisip     6.995208
# 2573    nailalabas     6.995208
# 2574  naipaliwanag     6.995208
# 2575     naipanalo     6.995208
# 2576          naka     6.995208

# %%
#tfidf highest keywords ffnn nonhate
get_keywords(ffnn_nonhate.Tokens.values,'TFIDFFFNN_nonhate_keywords.csv').head(20)
# Out:
# TFIDFFFNN_nonhate_keywords.csv
#                Token  TFIDF_Value
# 0                 UP     6.906723
# 1822           natoy     6.906723
# 1811         narinig     6.906723
# 1812       narrative     6.906723
# 1814       nasubukan     6.906723
# 1815           nat'l     6.906723
# 1816      natagpuang     6.906723
# 1817         natasha     6.906723
# 1821            nato     6.906723
# 1823       natutunan     6.906723
# 1835          nenega     6.906723
# 1824        naubusan     6.906723
# 1825       nauubusan     6.906723
# 1826         nauulit     6.906723
# 1827         nawalan     6.906723
# 1828           nazis     6.906723
# 1829              nb     6.906723
# 1830          nctzen     6.906723
# 1810      napuntahan     6.906723
# 1809  napakapowerful     6.906723

# %%
#hate
ffnn_hate
# Out:
#                                                   Tweet  \
# 2                                ayan spoon feed sau ha
# 3     nagtataka okay lang suportahan communist group...
# 5                                     president satanas
# 6     divorce easy option married couples would allo...
# 8                                             abuchikik
# ...                                                 ...
# 1529  dami good accomplishment course list kang comp...
# 1530  mahirap makipag usap alam ulit ulitin tanong g...
# 1532       daughters girls anong klaseng katangahan yan
# 1533  even signature figure liberal party projects p...
# 1535             apologist hahahaa yung hubby si friend
#
#                                                  Tokens Label  Prediction
# 2                          [ayan, spoon, feed, sau, ha]  Hate    0.997534
# 3     [nagtataka, okay, lang, suportahan, communist,...  Hate    0.999990
# 5                                  [president, satanas]  Hate    0.999786
# 6     [divorce, easy, option, married, couples, woul...  Hate    0.957491
# 8                                           [abuchikik]  Hate    0.580445
# ...                                                 ...   ...         ...
# 1529  [dami, good, accomplishment, course, list, kan...  Hate    0.998877
# 1530  [mahirap, makipag, usap, alam, ulit, ulitin, t...  Hate    0.999114
# 1532  [daughters, girls, anong, klaseng, katangahan,...  Hate    0.999839
# 1533  [even, signature, figure, liberal, party, proj...  Hate    0.933070
# 1535      [apologist, hahahaa, yung, hubby, si, friend]  Hate    0.962922
#
# [802 rows x 4 columns]

# %%
#top ffnn hate sentences sorted by prediction
ffnn_hate_sortedbyprediction = ffnn_hate.sort_values(by=['Prediction'], ascending=False)
ffnn_hate_sortedbyprediction.to_csv('TFIDFFFNN_hate_results.csv', index=False)
ffnn_hate_sortedbyprediction
# Out:
#                                                   Tweet  \
# 979   rin ayaw makabalik lalo si makikita lang pag e...
# 770   anong gawin mong pagpapalit kulay robredo,hind...
# 990   marcosjr duwag ayaw umattend debate kayang ipa...
# 1381  philippines presidential frontrunner using tik...
# 1393  marcosjr duwag ayaw umattend debate kayang idi...
# ...                                                 ...
# 1344  open verse today nag pray humingi sign holly s...
# 773   since live bbm household aware support preside...
# 1192                           tinapos vp say president
# 756   lang twitter makakasabi si yung presidential b...
# 891                                  grabe si deserving
#
#                                                  Tokens Label  Prediction
# 979   [rin, ayaw, makabalik, lalo, si, makikita, lan...  Hate    1.000000
# 770   [anong, gawin, mong, pagpapalit, kulay, robred...  Hate    1.000000
# 990   [marcosjr, duwag, ayaw, umattend, debate, kaya...  Hate    1.000000
# 1381  [philippines, presidential, frontrunner, using...  Hate    1.000000
# 1393  [marcosjr, duwag, ayaw, umattend, debate, kaya...  Hate    1.000000
# ...                                                 ...   ...         ...
# 1344  [open, verse, today, nag, pray, humingi, sign,...  Hate    0.510466
# 773   [since, live, bbm, household, aware, support, ...  Hate    0.508727
# 1192                      [tinapos, vp, say, president]  Hate    0.504927
# 756   [lang, twitter, makakasabi, si, yung, presiden...  Hate    0.500604
# 891                              [grabe, si, deserving]  Hate    0.500423
#
# [802 rows x 4 columns]

# %%
#for nonhate
ffnn_nonhate
# Out:
#                                                   Tweet  \
# 0       future president iktr gaga stans spitting facts
# 1     tulungan nating manalo sara duterte darating e...
# 4     obviously attend smni debate owner network sum...
# 7                                louder madam president
# 9     tumindig bayan ipanalo makamasang gobyerno pan...
# ...                                                 ...
# 1523   bitin seconds ibinigay kay vp bigyan natin years
# 1526  ernesto asked makukumbinsi bansa asean magkais...
# 1528  gobyernong tapat angat buhay si enbie eleuteri...
# 1531  makakalimutan itong h2h grand rally napuntahan...
# 1534                                     best job woman
#
#                                                  Tokens     Label  Prediction
# 0     [future, president, iktr, gaga, stans, spittin...  Non-hate    0.953089
# 1     [tulungan, nating, manalo, sara, duterte, dara...  Non-hate    0.999718
# 4     [obviously, attend, smni, debate, owner, netwo...  Non-hate    0.985766
# 7                            [louder, madam, president]  Non-hate    0.990024
# 9     [tumindig, bayan, ipanalo, makamasang, gobyern...  Non-hate    0.999639
# ...                                                 ...       ...         ...
# 1523  [bitin, seconds, ibinigay, kay, vp, bigyan, na...  Non-hate    0.866358
# 1526  [ernesto, asked, makukumbinsi, bansa, asean, m...  Non-hate    0.999998
# 1528  [gobyernong, tapat, angat, buhay, si, enbie, e...  Non-hate    0.999999
# 1531  [makakalimutan, itong, h2h, grand, rally, napu...  Non-hate    0.999829
# 1534                                 [best, job, woman]  Non-hate    0.999997
#
# [734 rows x 4 columns]

# %%
#top ffnn nonhate sentences sorted by prediction
ffnn_nonhate_sortedbyprediction = ffnn_nonhate.sort_values(by=['Prediction'], ascending=False)
ffnn_nonhate_sortedbyprediction.to_csv('TFIDFFFNN_nonhate_results.csv', index=False)
ffnn_nonhate_sortedbyprediction
# Out:
#                                                   Tweet  \
# 307   ngayong darating halalan tatanglaw buong bayan...
# 36    ngayong darating halalan tatanglaw buong bayan...
# 98    ngayong darating halalan tatanglaw buong bayan...
# 1243  gobyernong tapat angat buhay si alexa exo-ls n...
# 70    sama samang babangon terorista kay frame japet...
# ...                                                 ...
# 896   winners losers cnn philippines presidential de...
# 1272  knows vp strongest presidential candidate qual...
# 1426  presidential aspirant running mate walden bell...
# 380                           chillin like villain lang
# 89                                  mahal mahal mwahhhh
#
#                                                  Tokens     Label  Prediction
# 307   [ngayong, darating, halalan, tatanglaw, buong,...  Non-hate    1.000000
# 36    [ngayong, darating, halalan, tatanglaw, buong,...  Non-hate    1.000000
# 98    [ngayong, darating, halalan, tatanglaw, buong,...  Non-hate    1.000000
# 1243  [gobyernong, tapat, angat, buhay, si, alexa, e...  Non-hate    1.000000
# 70    [sama, samang, babangon, terorista, kay, frame...  Non-hate    1.000000
# ...                                                 ...       ...         ...
# 896   [winners, losers, cnn, philippines, presidenti...  Non-hate    0.526034
# 1272  [knows, vp, strongest, presidential, candidate...  Non-hate    0.517339
# 1426  [presidential, aspirant, running, mate, walden...  Non-hate    0.515126
# 380                      [chillin, like, villain, lang]  Non-hate    0.510502
# 89                              [mahal, mahal, mwahhhh]  Non-hate    0.501120
#
# [734 rows x 4 columns]

# %%
#For fasttext results

# %%
fastTextCNN_test_results.to_csv('fastTextCNN_test_results.csv', index=False)
fastTextCNN_test_results
# Out:
#                                                   Tweet  \
# 0       future president iktr gaga stans spitting facts
# 1     tulungan nating manalo sara duterte darating e...
# 2                                ayan spoon feed sau ha
# 3     nagtataka okay lang suportahan communist group...
# 4     obviously attend smni debate owner network sum...
# ...                                                 ...
# 1531  makakalimutan itong h2h grand rally napuntahan...
# 1532       daughters girls anong klaseng katangahan yan
# 1533  even signature figure liberal party projects p...
# 1534                                     best job woman
# 1535             apologist hahahaa yung hubby si friend
#
#                                                  Tokens     Label  Prediction
# 0     [future, president, iktr, gaga, stans, spittin...      Hate    0.810157
# 1     [tulungan, nating, manalo, sara, duterte, dara...  Non-hate    0.043186
# 2                          [ayan, spoon, feed, sau, ha]      Hate    0.960285
# 3     [nagtataka, okay, lang, suportahan, communist,...      Hate    0.888411
# 4     [obviously, attend, smni, debate, owner, netwo...      Hate    0.521093
# ...                                                 ...       ...         ...
# 1531  [makakalimutan, itong, h2h, grand, rally, napu...  Non-hate    0.206106
# 1532  [daughters, girls, anong, klaseng, katangahan,...      Hate    0.965818
# 1533  [even, signature, figure, liberal, party, proj...      Hate    0.924295
# 1534                                 [best, job, woman]  Non-hate    0.000526
# 1535      [apologist, hahahaa, yung, hubby, si, friend]      Hate    0.725103
#
# [1536 rows x 4 columns]

# %%
groupedby_cnn_label = fastTextCNN_test_results.groupby(fastTextCNN_test_results.Label)
#group by label
cnn_nonhate = groupedby_cnn_label.get_group("Non-hate")
cnn_hate = groupedby_cnn_label.get_group("Hate")

# %%
#get top keywords by tfidf

# %%
#fasttextcnn highest keywords nonhate
get_keywords(cnn_nonhate.Tokens.values,'fastTextCNN_nonhate_keywords.csv').head(20)
# Out:
# fastTextCNN_nonhate_keywords.csv
#               Token  TFIDF_Value
# 0                UP     6.902633
# 1670        neutral     6.902633
# 1664     nepomuceno     6.902633
# 1665          nerds     6.902633
# 1666           neri     6.902633
# 1667          nerve     6.902633
# 1668           nery     6.902633
# 1669        network     6.902633
# 1671     neutrality     6.902633
# 1662  neighbourhood     6.902633
# 1677     nga!hahaha     6.902633
# 1679         ngayun     6.902633
# 1680         nginig     6.902633
# 1681          ngiti     6.902633
# 1683          night     6.902633
# 1684          nimfa     6.902633
# 1663        neither     6.902633
# 1661     negativity     6.902633
# 1636       nangyari     6.902633
# 1648        natasha     6.902633

# %%
#fasttextcnn highest keywords hate
get_keywords(cnn_hate.Tokens.values,'fastTextCNN_hate_keywords.csv').head(20)
# Out:
# fastTextCNN_hate_keywords.csv
#              Token  TFIDF_Value
# 0          aabutin     6.998937
# 2698     nagtataka     6.998937
# 2700  nagtotorture     6.998937
# 2701    nagtutulak     6.998937
# 2702       nahagip     6.998937
# 2703      nahehelo     6.998937
# 2704      nahihiya     6.998937
# 2705      nahimlay     6.998937
# 2706        nahiya     6.998937
# 2707      naiambag     6.998937
# 2708       naiisip     6.998937
# 2709    nailalabas     6.998937
# 2710  naipaliwanag     6.998937
# 2711     naipanalo     6.998937
# 2712       naisama     6.998937
# 2713         naive     6.998937
# 2714          naka     6.998937
# 2715     naka-move     6.998937
# 2716    nakabuntis     6.998937
# 2718  nakaka-drain     6.998937

# %%
#top cnn hate sentences sorted by prediction
cnn_hate_sortedbyprediction = cnn_hate.sort_values(by=['Prediction'], ascending=False)
cnn_hate_sortedbyprediction.to_csv('fastTextCNN_hate_results.csv', index=False)
cnn_hate_sortedbyprediction
# Out:
#                                                   Tweet  \
# 257   nagsasabing bobo si gago mas bobo kayo hahahah...
# 373   anong ikinagagalit is/ko color fuchsia bang pr...
# 200           taas standard pulitiko bobo nga tanga pwe
# 578      mahilig gumamit salitang tanga bobo supporters
# 416   started klase demonyo ugali tutlaran sumusunod...
# ...                                                 ...
# 1063  makes sense tapped tiktok bolster presidential...
# 592                                 happening around us
# 267   strikes escapee asylum hiding plain sight pres...
# 263                                also economist po si
# 198   patay po si jesse god bless soul di po cya pwe...
#
#                                                  Tokens Label  Prediction
# 257   [nagsasabing, bobo, si, gago, mas, bobo, kayo,...  Hate    0.999999
# 373   [anong, ikinagagalit, is/ko, color, fuchsia, b...  Hate    0.999994
# 200   [taas, standard, pulitiko, bobo, nga, tanga, pwe]  Hate    0.999992
# 578   [mahilig, gumamit, salitang, tanga, bobo, supp...  Hate    0.999987
# 416   [started, klase, demonyo, ugali, tutlaran, sum...  Hate    0.999983
# ...                                                 ...   ...         ...
# 1063  [makes, sense, tapped, tiktok, bolster, presid...  Hate    0.506203
# 592                             [happening, around, us]  Hate    0.504712
# 267   [strikes, escapee, asylum, hiding, plain, sigh...  Hate    0.504574
# 263                           [also, economist, po, si]  Hate    0.504110
# 198   [patay, po, si, jesse, god, bless, soul, di, p...  Hate    0.500355
#
# [805 rows x 4 columns]

# %%
cnn_nonhate
# Out:
#                                                   Tweet  \
# 1     tulungan nating manalo sara duterte darating e...
# 5                                     president satanas
# 7                                louder madam president
# 8                                             abuchikik
# 9     tumindig bayan ipanalo makamasang gobyerno pan...
# ...                                                 ...
# 1527  last hour campaign season presidential frontru...
# 1528  gobyernong tapat angat buhay si enbie eleuteri...
# 1530  mahirap makipag usap alam ulit ulitin tanong g...
# 1531  makakalimutan itong h2h grand rally napuntahan...
# 1534                                     best job woman
#
#                                                  Tokens     Label  Prediction
# 1     [tulungan, nating, manalo, sara, duterte, dara...  Non-hate    0.043186
# 5                                  [president, satanas]  Non-hate    0.247005
# 7                            [louder, madam, president]  Non-hate    0.066984
# 8                                           [abuchikik]  Non-hate    0.464315
# 9     [tumindig, bayan, ipanalo, makamasang, gobyern...  Non-hate    0.046178
# ...                                                 ...       ...         ...
# 1527  [last, hour, campaign, season, presidential, f...  Non-hate    0.117405
# 1528  [gobyernong, tapat, angat, buhay, si, enbie, e...  Non-hate    0.001499
# 1530  [mahirap, makipag, usap, alam, ulit, ulitin, t...  Non-hate    0.327363
# 1531  [makakalimutan, itong, h2h, grand, rally, napu...  Non-hate    0.206106
# 1534                                 [best, job, woman]  Non-hate    0.000526
#
# [731 rows x 4 columns]

# %%
#top cnn nonhate sentences sorted by prediction
cnn_nonhate_sortedbyprediction = cnn_nonhate.sort_values(by=['Prediction'], ascending=True)
cnn_nonhate_sortedbyprediction.to_csv('fastTextCNN_nonhate_results.csv', index=False)
cnn_nonhate_sortedbyprediction
# Out:
#                                                   Tweet  \
# 1023                           best job woman president
# 1500                                best job woman puso
# 79                             thethe best job woman vp
# 835   true leaders show po darating best job woman p...
# 666   darating best job woman ipanalo natin katropa ...
# ...                                                 ...
# 934   there's lot people government position qualifi...
# 1034  gma artists abs-cbn artists supporting one can...
# 232   hello po hehehehe fact check lng po https://t....
# 216   former senator antonio trillanes eyes senate r...
# 1067                                     talaga lolo si
#
#                                                  Tokens     Label  Prediction
# 1023                      [best, job, woman, president]  Non-hate    0.000145
# 1500                           [best, job, woman, puso]  Non-hate    0.000159
# 79                       [thethe, best, job, woman, vp]  Non-hate    0.000162
# 835   [true, leaders, show, po, darating, best, job,...  Non-hate    0.000172
# 666   [darating, best, job, woman, ipanalo, natin, k...  Non-hate    0.000207
# ...                                                 ...       ...         ...
# 934   [there's, lot, people, government, position, q...  Non-hate    0.492148
# 1034  [gma, artists, abs-cbn, artists, supporting, o...  Non-hate    0.496235
# 232   [hello, po, hehehehe, fact, check, lng, po, ht...  Non-hate    0.496275
# 216   [former, senator, antonio, trillanes, eyes, se...  Non-hate    0.499349
# 1067                                 [talaga, lolo, si]  Non-hate    0.499880
#
# [731 rows x 4 columns]
