# %%
#import necessary libraries
import pandas as pd
import csv
import re
import validators
import emoji
import unidecode
import nltk
import pickle
nltk.download('stopwords')
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.tokenize import WhitespaceTokenizer
from itertools import chain
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import keras
from keras.preprocessing import sequence
import tensorflow as tf
from keras import Input
from keras import optimizers
from keras import backend as K
import torch
from keras import regularizers
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_blobs
from keras.models import Sequential
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.models import load_model
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectPercentile, f_classif

import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import np_utils
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from itertools import chain

from tqdm import tqdm
from gensim.models import fasttext
from gensim.test.utils import datapath
import os, re, csv, math, codecs, pickle, nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kirby
# [nltk_data]     Wenceslao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Load test and testresutls   

with open('x_test.pkl', 'rb') as file:
    x_test = pickle.load(file)
    
with open('y_test.pkl', 'rb') as file:
    y_test = pickle.load(file)
    
with open('fastTextCNN_test_results.pkl', 'rb') as file:
    fastTextCNN_test_results = pickle.load(file) 
    
with open('TFIDFFFNN_test_results.pkl', 'rb') as file:
    TFIDFFFNN_test_results = pickle.load(file)  
    
#Convert Labels from Strings to categorical Integers {Non-Hate = 1, Hate = 0}


df_ytest = pd.DataFrame(y_test, columns = ['Label'])

fastTextCNN_test_results.columns = ['Tokens', 'Label', 'Prediction']
fastTextCNN_test_results['Label'] = fastTextCNN_test_results['Label'].str.get(0)
fastTextCNN_test_results['Prediction'] = fastTextCNN_test_results['Prediction'].str.get(0)

fastTextCNN_tweets_joined = []

for i in range(len(fastTextCNN_test_results.Tokens.values)):
    tweet = " ".join(fastTextCNN_test_results.Tokens.values[i])
    fastTextCNN_tweets_joined.append(tweet)
    
fastTextCNN_test_results.insert(0, "Tweet", fastTextCNN_tweets_joined, True)


TFIDFFFNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

tfidfffnn_tweets_joined = []
for i in range(len(TFIDFFFNN_test_results.Tokens.values)):
    tweet = " ".join(TFIDFFFNN_test_results.Tokens.values[i])
    tfidfffnn_tweets_joined.append(tweet)
    
TFIDFFFNN_test_results.insert(0, "Tweet", tfidfffnn_tweets_joined, True)
#TFIDFFFNN_test_results['Label'] = TFIDFFFNN_test_results['Label'].str.get(0)
#TFIDFFFNN_test_results['Prediction'] = TFIDFFFNN_test_results['Prediction'].str.get(0)
#flatten training set for fitting on tfidf
#x_train_fit = list(chain.from_iterable(x_train))

mapping = {'Non-hate': 0, 'Hate': 1}
mapping_reverse = {0: 'Non-hate', 1: 'Hate'}
fastTextCNN_test_results = fastTextCNN_test_results.replace({'Label': mapping_reverse})
TFIDFFFNN_test_results = TFIDFFFNN_test_results.replace({'Label': mapping_reverse})
df_ytest = df_ytest.replace({'Label': mapping})

# %%
#collect index of misclassified and remove from results


fasttext_misclassified = []
tfidf_misclassified = []

for i in range(len(y_test)):
    if(y_test[i] != fastTextCNN_test_results.Label.values[i]):
        fasttext_misclassified.append(i)
        
    if(y_test[i] != TFIDFFFNN_test_results.Label.values[i]):
        tfidf_misclassified.append(i)
    
print(len(fasttext_misclassified))
print(len(tfidf_misclassified))

#remove misclassified
fastTextCNN_test_results.drop(fasttext_misclassified, inplace = True )
TFIDFFFNN_test_results.drop(tfidf_misclassified, inplace = True )

print()

# %%
def dummy_fun(doc):
    return doc

def get_keywords(data,filename):
    print(filename)
    tfidf = TfidfVectorizer(
        analyzer='word',
        tokenizer=dummy_fun,
        preprocessor=dummy_fun,
        token_pattern=None)  

    #fit text to tfidf
    tfidf.fit_transform(data)


    fasttext_dict = list(zip(tfidf.get_feature_names(), tfidf.idf_))
    fasttext_df = pd.DataFrame(fasttext_dict, columns = ['Token', 'TFIDF_Value'])
    fasttextresults_label_sorted = fasttext_df.sort_values(by=['TFIDF_Value'], ascending=False)
    fasttextresults_label_sorted.to_csv(filename, index=False)
    
    return fasttextresults_label_sorted

# %%
TFIDFFFNN_test_results.to_csv('TFIDFFFNN_test_results.csv', index=False)
TFIDFFFNN_test_results
# Out:
#                                                  Tweet  \
# 0               day ends balota kiko pangilinan kasama
# 1                                      president cutie
# 2    first day covid pandemic via wow vp true leade...
# 3      presidente bise presidente kiko pangilininannnn
# 4    dalawang pangakong binitiwan sakaling ibotong ...
# ..                                                 ...
# 507  robredo's final speech comelec's presidential ...
# 508  sinungaling umpisa sinungaling kahuli hulihan ...
# 509  siniraan pilipinas last six years wants reward...
# 510                   manalo matalo kay hganggang dulo
# 511  si niyo sakit malapit mastroke ata palibhasa n...
#
#                                                 Tokens     Label  Prediction
# 0        [day, ends, balota, kiko, pangilinan, kasama]  Non-hate    0.999681
# 1                                   [president, cutie]  Non-hate    1.000000
# 2    [first, day, covid, pandemic, via, wow, vp, tr...  Non-hate    0.999829
# 3    [presidente, bise, presidente, kiko, pangilini...  Non-hate    0.983980
# 4    [dalawang, pangakong, binitiwan, sakaling, ibo...  Non-hate    0.999793
# ..                                                 ...       ...         ...
# 507  [robredo's, final, speech, comelec's, presiden...  Non-hate    0.991915
# 508  [sinungaling, umpisa, sinungaling, kahuli, hul...      Hate    1.000000
# 509  [siniraan, pilipinas, last, six, years, wants,...      Hate    0.985040
# 510             [manalo, matalo, kay, hganggang, dulo]  Non-hate    0.999960
# 511  [si, niyo, sakit, malapit, mastroke, ata, pali...      Hate    0.999801
#
# [512 rows x 4 columns]

# %%
groupedby_ffnn_label = TFIDFFFNN_test_results.groupby(TFIDFFFNN_test_results.Label)

#group by label
ffnn_nonhate = groupedby_ffnn_label.get_group("Non-hate")
ffnn_hate = groupedby_ffnn_label.get_group("Hate")

# %%
#tfidf highest keywords ffnn hate
get_keywords(ffnn_hate.Tokens.values,'TFIDFFFNN_hate_keywords.csv').head(20)
# Out:
# TFIDFFFNN_hate_keywords.csv
#           Token  TFIDF_Value
# 0         aaral     5.879007
# 1182       nman     5.879007
# 1197       nyan     5.879007
# 1194     number     5.879007
# 1192     noynoy     5.879007
# 1191    nothing     5.879007
# 1190  nostalgia     5.879007
# 1189   northern     5.879007
# 1188     normal     5.879007
# 1186        non     5.879007
# 1185      noise     5.879007
# 1183        nmn     5.879007
# 1181       nlng     5.879007
# 1201  objective     5.879007
# 1180     niyong     5.879007
# 1178      niyan     5.879007
# 1177      ninyo     5.879007
# 1176    ninakaw     5.879007
# 1175       nina     5.879007
# 1174     niloko     5.879007

# %%
#tfidf highest keywords ffnn nonhate
get_keywords(ffnn_nonhate.Tokens.values,'TFIDFFFNN_nonhate_keywords.csv').head(20)
# Out:
# TFIDFFFNN_nonhate_keywords.csv
#             Token  TFIDF_Value
# 0        aadvance     5.832306
# 788   ordinaryong     5.832306
# 795     pag-atras     5.832306
# 794       pag-asa     5.832306
# 792  pa-reach-out     5.832306
# 791        owohhh     5.832306
# 790         ought     5.832306
# 789        others     5.832306
# 786    opposition     5.832306
# 817      pamasahe     5.832306
# 785       oponion     5.832306
# 784            oo     5.832306
# 782          okay     5.832306
# 781         okada     5.832306
# 780          ohhh     5.832306
# 779           ohh     5.832306
# 796      pag-ibig     5.832306
# 797    pagba-vlog     5.832306
# 799          page     5.832306
# 800         pagka     5.832306

# %%
#hate
ffnn_hate
# Out:
#                                                  Tweet  \
# 6    pagsinabi sarah sasabihin niyo sarah geronimo ...
# 7    ferdinand jr.--the unapologetic corrupt dictat...
# 8    really true millenials rooting since experienc...
# 11   natatae ata dami kagad kuda kay edi binasag ka...
# 13   nga saken worth si maam porket lutang ibang in...
# ..                                                 ...
# 504  mirror image duterte si parehong palaaway bast...
# 506       ilocana mas madami pang credentials kesa kay
# 508  sinungaling umpisa sinungaling kahuli hulihan ...
# 509  siniraan pilipinas last six years wants reward...
# 511  si niyo sakit malapit mastroke ata palibhasa n...
#
#                                                 Tokens Label  Prediction
# 6    [pagsinabi, sarah, sasabihin, niyo, sarah, ger...  Hate    0.999997
# 7    [ferdinand, jr.--the, unapologetic, corrupt, d...  Hate    0.999953
# 8    [really, true, millenials, rooting, since, exp...  Hate    0.997435
# 11   [natatae, ata, dami, kagad, kuda, kay, edi, bi...  Hate    0.998242
# 13   [nga, saken, worth, si, maam, porket, lutang, ...  Hate    0.999901
# ..                                                 ...   ...         ...
# 504  [mirror, image, duterte, si, parehong, palaawa...  Hate    0.999910
# 506  [ilocana, mas, madami, pang, credentials, kesa...  Hate    0.908417
# 508  [sinungaling, umpisa, sinungaling, kahuli, hul...  Hate    1.000000
# 509  [siniraan, pilipinas, last, six, years, wants,...  Hate    0.985040
# 511  [si, niyo, sakit, malapit, mastroke, ata, pali...  Hate    0.999801
#
# [262 rows x 4 columns]

# %%
#top ffnn hate sentences sorted by prediction
ffnn_hate_sortedbyprediction = ffnn_hate.sort_values(by=['Prediction'], ascending=False)
ffnn_hate_sortedbyprediction.to_csv('TFIDFFFNN_hate_results.csv', index=False)
ffnn_hate_sortedbyprediction
# Out:
#                                                  Tweet  \
# 274  smni debates matter nice debate biased shunga ...
# 119  obvious namang binigay yung questions kay liar...
# 487  marcosjr duwag ayaw umattend debate kayang ipa...
# 72   marcosjr duwag ayaw umattend debate kayang ipa...
# 461                                         magnanakaw
# ..                                                 ...
# 364                               naneto pinagsasasabe
# 177                                remain impressed mr
# 270                                          redtagger
# 413       niyo magpalit kulay parin mababago dependent
# 315     think election comes everyone else noise point
#
#                                                 Tokens Label  Prediction
# 274  [smni, debates, matter, nice, debate, biased, ...  Hate    1.000000
# 119  [obvious, namang, binigay, yung, questions, ka...  Hate    1.000000
# 487  [marcosjr, duwag, ayaw, umattend, debate, kaya...  Hate    1.000000
# 72   [marcosjr, duwag, ayaw, umattend, debate, kaya...  Hate    1.000000
# 461                                       [magnanakaw]  Hate    1.000000
# ..                                                 ...   ...         ...
# 364                            [naneto, pinagsasasabe]  Hate    0.547677
# 177                            [remain, impressed, mr]  Hate    0.547677
# 270                                        [redtagger]  Hate    0.547677
# 413  [niyo, magpalit, kulay, parin, mababago, depen...  Hate    0.531275
# 315  [think, election, comes, everyone, else, noise...  Hate    0.520990
#
# [262 rows x 4 columns]

# %%
#for nonhate
ffnn_nonhate
# Out:
#                                                  Tweet  \
# 0               day ends balota kiko pangilinan kasama
# 1                                      president cutie
# 2    first day covid pandemic via wow vp true leade...
# 3      presidente bise presidente kiko pangilininannnn
# 4    dalawang pangakong binitiwan sakaling ibotong ...
# ..                                                 ...
# 499  davao del sur governor cagas endorses presiden...
# 503  great mother divine mother restless children e...
# 505  jodi sta maria nag-house-to-house campaign kik...
# 507  robredo's final speech comelec's presidential ...
# 510                   manalo matalo kay hganggang dulo
#
#                                                 Tokens     Label  Prediction
# 0        [day, ends, balota, kiko, pangilinan, kasama]  Non-hate    0.999681
# 1                                   [president, cutie]  Non-hate    1.000000
# 2    [first, day, covid, pandemic, via, wow, vp, tr...  Non-hate    0.999829
# 3    [presidente, bise, presidente, kiko, pangilini...  Non-hate    0.983980
# 4    [dalawang, pangakong, binitiwan, sakaling, ibo...  Non-hate    0.999793
# ..                                                 ...       ...         ...
# 499  [davao, del, sur, governor, cagas, endorses, p...  Non-hate    0.999429
# 503  [great, mother, divine, mother, restless, chil...  Non-hate    0.966261
# 505  [jodi, sta, maria, nag-house-to-house, campaig...  Non-hate    1.000000
# 507  [robredo's, final, speech, comelec's, presiden...  Non-hate    0.991915
# 510             [manalo, matalo, kay, hganggang, dulo]  Non-hate    0.999960
#
# [250 rows x 4 columns]

# %%
#top ffnn nonhate sentences sorted by prediction
ffnn_nonhate_sortedbyprediction = ffnn_nonhate.sort_values(by=['Prediction'], ascending=False)
ffnn_nonhate_sortedbyprediction.to_csv('TFIDFFFNN_nonhate_results.csv', index=False)
ffnn_nonhate_sortedbyprediction
# Out:
#                                                  Tweet  \
# 243  pag-asa yung tumutulak mangarap dulo kadiliman...
# 21                                     president cutie
# 1                                      president cutie
# 292  madam president maria leonor gerona cutie true...
# 300  please watch let's attract manifest vice presi...
# ..                                                 ...
# 348  update closing statement smni's presidential d...
# 452          vp clearly ready th president philippines
# 414             inday sara duterte let us unite future
# 47   andami patutsada politiko ba talaga iboboto vo...
# 101  tf think majority kakampinks esp residents nag...
#
#                                                 Tokens     Label  Prediction
# 243  [pag-asa, yung, tumutulak, mangarap, dulo, kad...  Non-hate    1.000000
# 21                                  [president, cutie]  Non-hate    1.000000
# 1                                   [president, cutie]  Non-hate    1.000000
# 292  [madam, president, maria, leonor, gerona, cuti...  Non-hate    1.000000
# 300  [please, watch, let's, attract, manifest, vice...  Non-hate    1.000000
# ..                                                 ...       ...         ...
# 348  [update, closing, statement, smni's, president...  Non-hate    0.608880
# 452   [vp, clearly, ready, th, president, philippines]  Non-hate    0.565044
# 414     [inday, sara, duterte, let, us, unite, future]  Non-hate    0.556530
# 47   [andami, patutsada, politiko, ba, talaga, ibob...  Non-hate    0.533093
# 101  [tf, think, majority, kakampinks, esp, residen...  Non-hate    0.507339
#
# [250 rows x 4 columns]

# %%
#For fasttext results

# %%
fastTextCNN_test_results.to_csv('fastTextCNN_test_results.csv', index=False)
fastTextCNN_test_results
# Out:
#                                                  Tweet  \
# 0               day ends balota kiko pangilinan kasama
# 1                                      president cutie
# 2    first day covid pandemic via wow vp true leade...
# 3      presidente bise presidente kiko pangilininannnn
# 4    dalawang pangakong binitiwan sakaling ibotong ...
# ..                                                 ...
# 507  robredo's final speech comelec's presidential ...
# 508  sinungaling umpisa sinungaling kahuli hulihan ...
# 509  siniraan pilipinas last six years wants reward...
# 510                   manalo matalo kay hganggang dulo
# 511  si niyo sakit malapit mastroke ata palibhasa n...
#
#                                                 Tokens     Label  Prediction
# 0        [day, ends, balota, kiko, pangilinan, kasama]  Non-hate    0.016057
# 1                                   [president, cutie]  Non-hate    0.016355
# 2    [first, day, covid, pandemic, via, wow, vp, tr...  Non-hate    0.099809
# 3    [presidente, bise, presidente, kiko, pangilini...  Non-hate    0.021594
# 4    [dalawang, pangakong, binitiwan, sakaling, ibo...  Non-hate    0.158146
# ..                                                 ...       ...         ...
# 507  [robredo's, final, speech, comelec's, presiden...  Non-hate    0.171745
# 508  [sinungaling, umpisa, sinungaling, kahuli, hul...      Hate    0.943714
# 509  [siniraan, pilipinas, last, six, years, wants,...      Hate    0.907931
# 510             [manalo, matalo, kay, hganggang, dulo]  Non-hate    0.130683
# 511  [si, niyo, sakit, malapit, mastroke, ata, pali...      Hate    0.998275
#
# [512 rows x 4 columns]

# %%
groupedby_cnn_label = fastTextCNN_test_results.groupby(fastTextCNN_test_results.Label)
#group by label
cnn_nonhate = groupedby_cnn_label.get_group("Non-hate")
cnn_hate = groupedby_cnn_label.get_group("Hate")

# %%
#get top keywords by tfidf

# %%
#fasttextcnn highest keywords nonhate
get_keywords(cnn_nonhate.Tokens.values,'fastTextCNN_nonhate_keywords.csv').head(20)
# Out:
# fastTextCNN_nonhate_keywords.csv
#                    Token  TFIDF_Value
# 0               aadvance     5.783316
# 657              oponion     5.783316
# 660          ordinaryong     5.783316
# 661         pa-reach-out     5.783316
# 663              pag-asa     5.783316
# 664            pag-atras     5.783316
# 665             pag-ibig     5.783316
# 666           pagba-vlog     5.783316
# 668                 page     5.783316
# 669                pagka     5.783316
# 670           pagkakaisa     5.783316
# 672                pagod     5.783316
# 673             pagpunta     5.783316
# 674            pagsulong     5.783316
# 676            pagtingin     5.783316
# 677            pagtitiis     5.783316
# 678        pagtratrabaho     5.783316
# 679  pakikikipagkampanya     5.783316
# 680        pakikipagusap     5.783316
# 681           palampasin     5.783316

# %%
#fasttextcnn highest keywords hate
get_keywords(cnn_hate.Tokens.values,'fastTextCNN_hate_keywords.csv').head(20)
# Out:
# fastTextCNN_hate_keywords.csv
#           Token  TFIDF_Value
# 0         aaral     5.923624
# 1280   nilangaw     5.923624
# 1296   northern     5.923624
# 1295     normal     5.923624
# 1293        non     5.923624
# 1292      noise     5.923624
# 1290        nmn     5.923624
# 1289       nman     5.923624
# 1288       nlng     5.923624
# 1285      niyan     5.923624
# 1283    ninakaw     5.923624
# 1282       nina     5.923624
# 1281     niloko     5.923624
# 1279  nila.sila     5.923624
# 1298       note     5.923624
# 1278      nikki     5.923624
# 1276     ngsabi     5.923624
# 1271    neutral     5.923624
# 1270   networks     5.923624
# 1269    network     5.923624

# %%
#top cnn hate sentences sorted by prediction
cnn_hate_sortedbyprediction = cnn_hate.sort_values(by=['Prediction'], ascending=False)
cnn_hate_sortedbyprediction.to_csv('fastTextCNN_hate_results.csv', index=False)
cnn_hate_sortedbyprediction
# Out:
#                                                  Tweet  \
# 411  wag mong gawing parang tanga lang..hindi duwag...
# 198  biggest flaws nating supporters eh yung pagigi...
# 195  bobo daw si bobo lagay yan pano lang yung di i...
# 137  asang asa pokwang mananalo wag masyadong umasa...
# 267  ulol yung nag sasabing i'm inc vote ulol nilok...
# ..                                                 ...
# 75                                          yt vvm com
# 314  someone hope throw daggers leading polls shoil...
# 222  brain exam quiz today kay tayooo owohhh ipanal...
# 38   imagine inc endorsed vp susundin nyo po utos c...
# 392  si tropang angat pinaglalaban bansang pilipina...
#
#                                                 Tokens Label  Prediction
# 411  [wag, mong, gawing, parang, tanga, lang..hindi...  Hate    0.999912
# 198  [biggest, flaws, nating, supporters, eh, yung,...  Hate    0.999888
# 195  [bobo, daw, si, bobo, lagay, yan, pano, lang, ...  Hate    0.999879
# 137  [asang, asa, pokwang, mananalo, wag, masyadong...  Hate    0.999410
# 267  [ulol, yung, nag, sasabing, i'm, inc, vote, ul...  Hate    0.999408
# ..                                                 ...   ...         ...
# 75                                      [yt, vvm, com]  Hate    0.522744
# 314  [someone, hope, throw, daggers, leading, polls...  Hate    0.520389
# 222  [brain, exam, quiz, today, kay, tayooo, owohhh...  Hate    0.518123
# 38   [imagine, inc, endorsed, vp, susundin, nyo, po...  Hate    0.509864
# 392  [si, tropang, angat, pinaglalaban, bansang, pi...  Hate    0.501979
#
# [274 rows x 4 columns]

# %%
cnn_nonhate
# Out:
#                                                  Tweet  \
# 0               day ends balota kiko pangilinan kasama
# 1                                      president cutie
# 2    first day covid pandemic via wow vp true leade...
# 3      presidente bise presidente kiko pangilininannnn
# 4    dalawang pangakong binitiwan sakaling ibotong ...
# ..                                                 ...
# 500                                      beat one time
# 503  great mother divine mother restless children e...
# 505  jodi sta maria nag-house-to-house campaign kik...
# 507  robredo's final speech comelec's presidential ...
# 510                   manalo matalo kay hganggang dulo
#
#                                                 Tokens     Label  Prediction
# 0        [day, ends, balota, kiko, pangilinan, kasama]  Non-hate    0.016057
# 1                                   [president, cutie]  Non-hate    0.016355
# 2    [first, day, covid, pandemic, via, wow, vp, tr...  Non-hate    0.099809
# 3    [presidente, bise, presidente, kiko, pangilini...  Non-hate    0.021594
# 4    [dalawang, pangakong, binitiwan, sakaling, ibo...  Non-hate    0.158146
# ..                                                 ...       ...         ...
# 500                                  [beat, one, time]  Non-hate    0.082277
# 503  [great, mother, divine, mother, restless, chil...  Non-hate    0.300837
# 505  [jodi, sta, maria, nag-house-to-house, campaig...  Non-hate    0.075493
# 507  [robredo's, final, speech, comelec's, presiden...  Non-hate    0.171745
# 510             [manalo, matalo, kay, hganggang, dulo]  Non-hate    0.130683
#
# [238 rows x 4 columns]

# %%
#top cnn nonhate sentences sorted by prediction
cnn_nonhate_sortedbyprediction = cnn_nonhate.sort_values(by=['Prediction'], ascending=True)
cnn_nonhate_sortedbyprediction.to_csv('fastTextCNN_nonhate_results.csv', index=False)
cnn_nonhate_sortedbyprediction
# Out:
#                                                  Tweet  \
# 470  nakikiisa pagsuporta kay vp sen kiko pangilina...
# 162                                  best job woman vp
# 243  pag-asa yung tumutulak mangarap dulo kadiliman...
# 309  si yel yarbz swith nakiki-isa pagsuporta kay v...
# 18   gobyernong tapat angat buhay si volleydeity bi...
# ..                                                 ...
# 456
# 328
# 60   mahihirap naman manggagawa naman umiikot kaniy...
# 350  robredo's credentials actions vice president p...
# 124  done downplay human rights abuses father's adm...
#
#                                                 Tokens     Label  Prediction
# 470  [nakikiisa, pagsuporta, kay, vp, sen, kiko, pa...  Non-hate    0.001549
# 162                             [best, job, woman, vp]  Non-hate    0.001608
# 243  [pag-asa, yung, tumutulak, mangarap, dulo, kad...  Non-hate    0.001744
# 309  [si, yel, yarbz, swith, nakiki-isa, pagsuporta...  Non-hate    0.002290
# 18   [gobyernong, tapat, angat, buhay, si, volleyde...  Non-hate    0.002733
# ..                                                 ...       ...         ...
# 456                                                 []  Non-hate    0.469718
# 328                                                 []  Non-hate    0.469718
# 60   [mahihirap, naman, manggagawa, naman, umiikot,...  Non-hate    0.492518
# 350  [robredo's, credentials, actions, vice, presid...  Non-hate    0.495714
# 124  [done, downplay, human, rights, abuses, father...  Non-hate    0.496208
#
# [238 rows x 4 columns]
