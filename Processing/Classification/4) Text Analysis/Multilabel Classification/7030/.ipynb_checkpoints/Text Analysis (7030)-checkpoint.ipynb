# %%
#import necessary libraries
import pandas as pd
import csv
import re
import validators
import emoji
import unidecode
import nltk
import pickle
nltk.download('stopwords')
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.tokenize import WhitespaceTokenizer
from itertools import chain
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import keras
from keras.preprocessing import sequence
import tensorflow as tf
from keras import Input
from keras import optimizers
from keras import backend as K
import torch
from keras import regularizers
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_blobs
from keras.models import Sequential
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.models import load_model
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectPercentile, f_classif

import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import np_utils
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from itertools import chain

from tqdm import tqdm
from gensim.models import fasttext
from gensim.test.utils import datapath
import os, re, csv, math, codecs, pickle, nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kirby
# [nltk_data]     Wenceslao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Load test and testresutls   

with open('x_test.pkl', 'rb') as file:
    x_test = pickle.load(file)
    
with open('y_test.pkl', 'rb') as file:
    y_test = pickle.load(file)
    
with open('fastTextCNN_test_results.pkl', 'rb') as file:
    fastTextCNN_test_results = pickle.load(file) 
    
with open('TFIDFFFNN_test_results.pkl', 'rb') as file:
    TFIDFFFNN_test_results = pickle.load(file)  
    
#Convert Labels from Strings to categorical Integers {Non-Hate = 1, Hate = 0}


df_ytest = pd.DataFrame(y_test, columns = ['Label'])

fastTextCNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

fastTextCNN_tweets_joined = []

for i in range(len(fastTextCNN_test_results.Tokens.values)):
    tweet = " ".join(fastTextCNN_test_results.Tokens.values[i])
    fastTextCNN_tweets_joined.append(tweet)
    
fastTextCNN_test_results.insert(0, "Tweet", fastTextCNN_tweets_joined, True)


TFIDFFFNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

tfidfffnn_tweets_joined = []
for i in range(len(TFIDFFFNN_test_results.Tokens.values)):
    tweet = " ".join(TFIDFFFNN_test_results.Tokens.values[i])
    tfidfffnn_tweets_joined.append(tweet)
    
TFIDFFFNN_test_results.insert(0, "Tweet", tfidfffnn_tweets_joined, True)
#TFIDFFFNN_test_results['Label'] = TFIDFFFNN_test_results['Label'].str.get(0)
#TFIDFFFNN_test_results['Prediction'] = TFIDFFFNN_test_results['Prediction'].str.get(0)
#flatten training set for fitting on tfidf
#x_train_fit = list(chain.from_iterable(x_train))

mapping = {'Positive': 0, 'Negative': 1, 'Neutral':2}
mapping_reverse = {0:'Positive', 1: 'Negative', 2: 'Neutral'}
fastTextCNN_test_results = fastTextCNN_test_results.replace({'Label': mapping_reverse})
TFIDFFFNN_test_results = TFIDFFFNN_test_results.replace({'Label': mapping_reverse})
df_ytest = df_ytest.replace({'Label': mapping})

# %%
#collect index of misclassified and remove from results


fasttext_misclassified = []
tfidf_misclassified = []

for i in range(len(y_test)):
    if(y_test[i] != fastTextCNN_test_results.Label.values[i]):
        fasttext_misclassified.append(i)
        
    if(y_test[i] != TFIDFFFNN_test_results.Label.values[i]):
        tfidf_misclassified.append(i)
    
print(len(fasttext_misclassified))
print(len(tfidf_misclassified))

#remove misclassified
fastTextCNN_test_results.drop(fasttext_misclassified, inplace = True )
TFIDFFFNN_test_results.drop(tfidf_misclassified, inplace = True )

print()
# Out:
# 864
# 868

# %%
fastTextCNN_test_results.shape
# Out:
# (1440, 4)

# %%
TFIDFFFNN_test_results.shape
# Out:
# (1436, 4)

# %%
TFIDFFFNN_test_results
# Out:
#                                                   Tweet  \
# 0     presidential candidate said would continue tra...
# 2     vp visits roxas city watch vp sen kiko pangili...
# 4     camp presidential frontrunner says endorsement...
# 5         toxic pinklawan impluwensya fushiang ina niyo
# 6     dios mabalos bicolandia miting avance puno say...
# ...                                                 ...
# 2296  nalang talaga nahihiya taong nagsasabing lutan...
# 2297  kita sasagutin baket si bbm presidente masasag...
# 2301  took blind test top candidates hahaha gates na...
# 2302                                that's first choice
# 2303  abc news young ones know dictator's dark past ...
#
#                                                  Tokens     Label  Prediction
# 0     [presidential, candidate, said, would, continu...   Neutral    0.987573
# 2     [vp, visits, roxas, city, watch, vp, sen, kiko...   Neutral    0.981569
# 4     [camp, presidential, frontrunner, says, endors...   Neutral    0.996996
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    1.000000
# 6     [dios, mabalos, bicolandia, miting, avance, pu...  Positive    0.918918
# ...                                                 ...       ...         ...
# 2296  [nalang, talaga, nahihiya, taong, nagsasabing,...  Negative    0.886088
# 2297  [kita, sasagutin, baket, si, bbm, presidente, ...  Negative    0.863481
# 2301  [took, blind, test, top, candidates, hahaha, g...   Neutral    0.792552
# 2302                            [that's, first, choice]  Positive    0.674450
# 2303  [abc, news, young, ones, know, dictator's, dar...  Negative    1.000000
#
# [1436 rows x 4 columns]

# %%
TFIDFFFNN_test_results.shape
# Out:
# (1436, 4)

# %%
print(len(df_ytest))
# Out:
# 2304

# %%
def dummy_fun(doc):
    return doc

def get_keywords(data,filename):
    print(filename)
    tfidf = TfidfVectorizer(
        analyzer='word',
        tokenizer=dummy_fun,
        preprocessor=dummy_fun,
        token_pattern=None)  

    #fit text to tfidf
    tfidf.fit_transform(data)


    fasttext_dict = list(zip(tfidf.get_feature_names(), tfidf.idf_))
    fasttext_df = pd.DataFrame(fasttext_dict, columns = ['Token', 'TFIDF_Value'])
    fasttextresults_label_sorted = fasttext_df.sort_values(by=['TFIDF_Value'], ascending=False)
    fasttextresults_label_sorted.to_csv(filename, index=False)
    
    return fasttextresults_label_sorted

# %%
TFIDFFFNN_test_results.to_csv('TFIDFFFNN_test_results.csv', index=False)
TFIDFFFNN_test_results
# Out:
#                                                   Tweet  \
# 0     presidential candidate said would continue tra...
# 2     vp visits roxas city watch vp sen kiko pangili...
# 4     camp presidential frontrunner says endorsement...
# 5         toxic pinklawan impluwensya fushiang ina niyo
# 6     dios mabalos bicolandia miting avance puno say...
# ...                                                 ...
# 2296  nalang talaga nahihiya taong nagsasabing lutan...
# 2297  kita sasagutin baket si bbm presidente masasag...
# 2301  took blind test top candidates hahaha gates na...
# 2302                                that's first choice
# 2303  abc news young ones know dictator's dark past ...
#
#                                                  Tokens     Label  Prediction
# 0     [presidential, candidate, said, would, continu...   Neutral    0.987573
# 2     [vp, visits, roxas, city, watch, vp, sen, kiko...   Neutral    0.981569
# 4     [camp, presidential, frontrunner, says, endors...   Neutral    0.996996
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    1.000000
# 6     [dios, mabalos, bicolandia, miting, avance, pu...  Positive    0.918918
# ...                                                 ...       ...         ...
# 2296  [nalang, talaga, nahihiya, taong, nagsasabing,...  Negative    0.886088
# 2297  [kita, sasagutin, baket, si, bbm, presidente, ...  Negative    0.863481
# 2301  [took, blind, test, top, candidates, hahaha, g...   Neutral    0.792552
# 2302                            [that's, first, choice]  Positive    0.674450
# 2303  [abc, news, young, ones, know, dictator's, dar...  Negative    1.000000
#
# [1436 rows x 4 columns]

# %%
groupedby_ffnn_label = TFIDFFFNN_test_results.groupby(TFIDFFFNN_test_results.Label)

#group by label
ffnn_positive = groupedby_ffnn_label.get_group("Positive")
ffnn_negative = groupedby_ffnn_label.get_group("Negative")
ffnn_neutral = groupedby_ffnn_label.get_group("Neutral")

# %%
#tfidf highest keywords ffnn positive
get_keywords(ffnn_positive.Tokens.values,'TFIDFFFNN_positive_keywords.csv').head(20)
# Out:
# TFIDFFFNN_positive_keywords.csv
#            Token  TFIDF_Value
# 0            FOR     6.474369
# 1035       ngiti     6.474369
# 1045        no.s     6.474369
# 1044        nmin     6.474369
# 1043   nkiki-isa     6.474369
# 1042         nio     6.474369
# 1040        nina     6.474369
# 1039       night     6.474369
# 1037        nice     6.474369
# 1036      ngunit     6.474369
# 1028     negosyo     6.474369
# 1048         non     6.474369
# 1027    negative     6.474369
# 1026       needs     6.474369
# 1023         ncr     6.474369
# 1022          nb     6.474369
# 1021      native     6.474369
# 1018  natin--ang     6.474369
# 1016    nasyonal     6.474369
# 1014      narrow     6.474369

# %%
#tfidf highest keywords ffnn negative
get_keywords(ffnn_negative.Tokens.values,'TFIDFFFNN_negative_keywords.csv').head(20)
# Out:
# TFIDFFFNN_negative_keywords.csv
#               Token  TFIDF_Value
# 0             aaral     6.596568
# 1951     nakakababa     6.596568
# 1953   nakakabastos     6.596568
# 1954  nakakadismaya     6.596568
# 1955     nakakaduda     6.596568
# 1957  nakakaintindi     6.596568
# 1958     nakakaiyak     6.596568
# 1959     nakakataas     6.596568
# 1960     nakakatawa     6.596568
# 1961        nakapag     6.596568
# 1962    nakapaligid     6.596568
# 1963     nakatulong     6.596568
# 1965   nakikinabang     6.596568
# 1967       nakilala     6.596568
# 1968     nakinabang     6.596568
# 1970      nalalaman     6.596568
# 1971        nalaman     6.596568
# 1973     nalulutang     6.596568
# 1977      namatayan     6.596568
# 1952   nakakabahala     6.596568

# %%
#tfidf highest keywords ffnn negative
get_keywords(ffnn_neutral.Tokens.values,'TFIDFFFNN_neutral_keywords.csv').head(20)
# Out:
# TFIDFFFNN_neutral_keywords.csv
#               Token  TFIDF_Value
# 0        Nationwide     6.354225
# 1283    opportunism     6.354225
# 1296            p.m     6.354225
# 1295            ovp     6.354225
# 1294       overturn     6.354225
# 1293        outside     6.354225
# 1292     outnumbers     6.354225
# 1291      otherwise     6.354225
# 1289       original     6.354225
# 1288  organizations     6.354225
# 1287           oras     6.354225
# 1286          opted     6.354225
# 1285   opposition's     6.354225
# 1282          ooout     6.354225
# 1299       pag-abot     6.354225
# 1280        ominous     6.354225
# 1279            old     6.354225
# 1277        okasyon     6.354225
# 1275           ohhh     6.354225
# 1274             oh     6.354225

# %%
#positive
ffnn_positive
# Out:
#                                                   Tweet  \
# 6     dios mabalos bicolandia miting avance puno say...
# 7     visible nakakatuwa hoping filipinos would open...
# 8     president vp kiko pangilinan tas si next week ...
# 11    i'm bad place seeing amazing women country mar...
# 20    gobyernong tapat angat buhay siyempre ipapanal...
# ...                                                 ...
# 2289                     manifesting president cutieeee
# 2290        cute ms pat ininvite facebook private group
# 2293  filipina pure catholic president vice presiden...
# 2295                          best job woman love madam
# 2302                                that's first choice
#
#                                                  Tokens     Label  Prediction
# 6     [dios, mabalos, bicolandia, miting, avance, pu...  Positive    0.918918
# 7     [visible, nakakatuwa, hoping, filipinos, would...  Positive    0.895188
# 8     [president, vp, kiko, pangilinan, tas, si, nex...  Positive    0.944991
# 11    [i'm, bad, place, seeing, amazing, women, coun...  Positive    0.685070
# 20    [gobyernong, tapat, angat, buhay, siyempre, ip...  Positive    0.999794
# ...                                                 ...       ...         ...
# 2289                 [manifesting, president, cutieeee]  Positive    0.994778
# 2290  [cute, ms, pat, ininvite, facebook, private, g...  Positive    0.983083
# 2293  [filipina, pure, catholic, president, vice, pr...  Positive    0.570338
# 2295                    [best, job, woman, love, madam]  Positive    0.843126
# 2302                            [that's, first, choice]  Positive    0.674450
#
# [476 rows x 4 columns]

# %%
#top ffnn hate sentences sorted by prediction
ffnn_positive_sortedbyprediction = ffnn_positive.sort_values(by=['Prediction'], ascending=False)
ffnn_positive_sortedbyprediction.to_csv('TFIDFFFNN_positive_results.csv', index=False)
ffnn_positive_sortedbyprediction
# Out:
#                                                   Tweet  \
# 767   gobyernong tapat angat buhay siyempre ipapanal...
# 2260  gobyernong tapat angat buhay siyempre ipapanal...
# 1531  talaga natin tunay pagbabago kakayahan puso pa...
# 1814  talaga natin tunay pagbabago kakayahan puso pa...
# 1127  talaga natin tunay pagbabago kakayahan puso pa...
# ...                                                 ...
# 857   vp president senator kiko pangilinan vice pres...
# 853                            sure president president
# 240   girls generation naki-isa pagsuporta kay vp ch...
# 1041  politics general ruin loren legarda's relation...
# 192   miss chanyeol paglabas si presidente claiming ...
#
#                                                  Tokens     Label  Prediction
# 767   [gobyernong, tapat, angat, buhay, siyempre, ip...  Positive    0.999999
# 2260  [gobyernong, tapat, angat, buhay, siyempre, ip...  Positive    0.999998
# 1531  [talaga, natin, tunay, pagbabago, kakayahan, p...  Positive    0.999996
# 1814  [talaga, natin, tunay, pagbabago, kakayahan, p...  Positive    0.999996
# 1127  [talaga, natin, tunay, pagbabago, kakayahan, p...  Positive    0.999996
# ...                                                 ...       ...         ...
# 857   [vp, president, senator, kiko, pangilinan, vic...  Positive    0.501548
# 853                        [sure, president, president]  Positive    0.500539
# 240   [girls, generation, naki-isa, pagsuporta, kay,...  Positive    0.491897
# 1041  [politics, general, ruin, loren, legarda's, re...  Positive    0.462734
# 192   [miss, chanyeol, paglabas, si, presidente, cla...  Positive    0.436619
#
# [476 rows x 4 columns]

# %%
#for negative
ffnn_negative
# Out:
#                                                   Tweet  \
# 5         toxic pinklawan impluwensya fushiang ina niyo
# 10    well really know agriculture sector tumatakbo ...
# 12    there's lutang ballot might nuisance candidate...
# 14    pinklawan trolls address volunteers reports na...
# 23    panu masasabi magnanakaw eh mahirap mong presi...
# ...                                                 ...
# 2286  looks like grandmother looks like mother heari...
# 2287  pala nabihisan basurero basura padin palang la...
# 2296  nalang talaga nahihiya taong nagsasabing lutan...
# 2297  kita sasagutin baket si bbm presidente masasag...
# 2303  abc news young ones know dictator's dark past ...
#
#                                                  Tokens     Label  Prediction
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    1.000000
# 10    [well, really, know, agriculture, sector, tuma...  Negative    0.999462
# 12    [there's, lutang, ballot, might, nuisance, can...  Negative    0.999890
# 14    [pinklawan, trolls, address, volunteers, repor...  Negative    0.999991
# 23    [panu, masasabi, magnanakaw, eh, mahirap, mong...  Negative    1.000000
# ...                                                 ...       ...         ...
# 2286  [looks, like, grandmother, looks, like, mother...  Negative    0.999997
# 2287  [pala, nabihisan, basurero, basura, padin, pal...  Negative    0.997761
# 2296  [nalang, talaga, nahihiya, taong, nagsasabing,...  Negative    0.886088
# 2297  [kita, sasagutin, baket, si, bbm, presidente, ...  Negative    0.863481
# 2303  [abc, news, young, ones, know, dictator's, dar...  Negative    1.000000
#
# [538 rows x 4 columns]

# %%
#top ffnn negative sentences sorted by prediction
ffnn_negative_sortedbyprediction = ffnn_negative.sort_values(by=['Prediction'], ascending=False)
ffnn_negative_sortedbyprediction.to_csv('TFIDFFFNN_negative_results.csv', index=False)
ffnn_negative_sortedbyprediction
# Out:
#                                                   Tweet  \
# 5         toxic pinklawan impluwensya fushiang ina niyo
# 1396  pansin niyo mahilig post alter sexcapades bakl...
# 385   ngarag shunga inendorse niyo si bobong narcos ...
# 444   philippines presidential frontrunner using tik...
# 521   years since philippines ousted dictator ferdin...
# ...                                                 ...
# 496   sorry jen bbm sara po solid malabo po manalo s...
# 2216  ba kaming kasama si binay rally alam legit sin...
# 471   protektahan oligarko iboto si kailangang manat...
# 709   naman talaga maipagkakaila talaga si vp tila m...
# 1543  ung supporters wag niyo po pag aksayahan boto ...
#
#                                                  Tokens     Label  Prediction
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    1.000000
# 1396  [pansin, niyo, mahilig, post, alter, sexcapade...  Negative    1.000000
# 385   [ngarag, shunga, inendorse, niyo, si, bobong, ...  Negative    1.000000
# 444   [philippines, presidential, frontrunner, using...  Negative    1.000000
# 521   [years, since, philippines, ousted, dictator, ...  Negative    1.000000
# ...                                                 ...       ...         ...
# 496   [sorry, jen, bbm, sara, po, solid, malabo, po,...  Negative    0.491323
# 2216  [ba, kaming, kasama, si, binay, rally, alam, l...  Negative    0.459860
# 471   [protektahan, oligarko, iboto, si, kailangang,...  Negative    0.455959
# 709   [naman, talaga, maipagkakaila, talaga, si, vp,...  Negative    0.397187
# 1543  [ung, supporters, wag, niyo, po, pag, aksayaha...  Negative    0.376051
#
# [538 rows x 4 columns]

# %%
#for neutral
ffnn_neutral
# Out:
#                                                   Tweet  \
# 0     presidential candidate said would continue tra...
# 2     vp visits roxas city watch vp sen kiko pangili...
# 4     camp presidential frontrunner says endorsement...
# 17              hope win president monday wanna see cry
# 21    presidential candidate ferdinand photographed ...
# ...                                                 ...
# 2276                                        mara cepeda
# 2279                                          president
# 2283  pag tinatanong taumbayan pangunahing pangangai...
# 2288                                    vp game changer
# 2301  took blind test top candidates hahaha gates na...
#
#                                                  Tokens    Label  Prediction
# 0     [presidential, candidate, said, would, continu...  Neutral    0.987573
# 2     [vp, visits, roxas, city, watch, vp, sen, kiko...  Neutral    0.981569
# 4     [camp, presidential, frontrunner, says, endors...  Neutral    0.996996
# 17      [hope, win, president, monday, wanna, see, cry]  Neutral    0.581588
# 21    [presidential, candidate, ferdinand, photograp...  Neutral    0.998923
# ...                                                 ...      ...         ...
# 2276                                     [mara, cepeda]  Neutral    0.534354
# 2279                                        [president]  Neutral    0.541078
# 2283  [pag, tinatanong, taumbayan, pangunahing, pang...  Neutral    0.988964
# 2288                                [vp, game, changer]  Neutral    0.562552
# 2301  [took, blind, test, top, candidates, hahaha, g...  Neutral    0.792552
#
# [422 rows x 4 columns]

# %%
#top ffnn neutral sentences sorted by prediction
ffnn_neutral_sortedbyprediction = ffnn_neutral.sort_values(by=['Prediction'], ascending=False)
ffnn_neutral_sortedbyprediction.to_csv('TFIDFFFNN_neutral_results.csv', index=False)
ffnn_neutral_sortedbyprediction
# Out:
#                                                   Tweet  \
# 2183  watch here's highlights day iloilo holds campa...
# 459   bu-usc endorses robredo-pangilinan tandem univ...
# 396   grand pasasalamat vp tropang angat paz plaza p...
# 130   get know closer presidential candidates get kn...
# 772   look presidential bet vp returns iloilo city t...
# ...                                                 ...
# 559   president kiko pangilinan vice president teddy...
# 1511             korek mapuans chanting kiko pangilinan
# 260                                 baka rin makatulong
# 505   pangngumbinse tawag dyan clearing rlly said ca...
# 1523              dami alam vp bat di nalang presidente
#
#                                                  Tokens    Label  Prediction
# 2183  [watch, here's, highlights, day, iloilo, holds...  Neutral    0.999998
# 459   [bu-usc, endorses, robredo-pangilinan, tandem,...  Neutral    0.999978
# 396   [grand, pasasalamat, vp, tropang, angat, paz, ...  Neutral    0.999967
# 130   [get, know, closer, presidential, candidates, ...  Neutral    0.999934
# 772   [look, presidential, bet, vp, returns, iloilo,...  Neutral    0.999914
# ...                                                 ...      ...         ...
# 559   [president, kiko, pangilinan, vice, president,...  Neutral    0.500018
# 1511       [korek, mapuans, chanting, kiko, pangilinan]  Neutral    0.498505
# 260                             [baka, rin, makatulong]  Neutral    0.487395
# 505   [pangngumbinse, tawag, dyan, clearing, rlly, s...  Neutral    0.451209
# 1523      [dami, alam, vp, bat, di, nalang, presidente]  Neutral    0.436155
#
# [422 rows x 4 columns]

# %%
#For fasttext results

# %%
fastTextCNN_test_results.to_csv('fastTextCNN_test_results.csv', index=False)
fastTextCNN_test_results
# Out:
#                                                   Tweet  \
# 0     presidential candidate said would continue tra...
# 1     kumalat text messages kandidatura malamang ant...
# 2     vp visits roxas city watch vp sen kiko pangili...
# 4     camp presidential frontrunner says endorsement...
# 5         toxic pinklawan impluwensya fushiang ina niyo
# ...                                                 ...
# 2291  tanginang reference yan dot com ahhahahahahahahha
# 2295                          best job woman love madam
# 2296  nalang talaga nahihiya taong nagsasabing lutan...
# 2301  took blind test top candidates hahaha gates na...
# 2303  abc news young ones know dictator's dark past ...
#
#                                                  Tokens     Label  Prediction
# 0     [presidential, candidate, said, would, continu...   Neutral    0.741291
# 1     [kumalat, text, messages, kandidatura, malaman...  Negative    0.922156
# 2     [vp, visits, roxas, city, watch, vp, sen, kiko...   Neutral    0.811498
# 4     [camp, presidential, frontrunner, says, endors...   Neutral    0.766553
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    0.938819
# ...                                                 ...       ...         ...
# 2291  [tanginang, reference, yan, dot, com, ahhahaha...  Negative    0.899021
# 2295                    [best, job, woman, love, madam]  Positive    0.835001
# 2296  [nalang, talaga, nahihiya, taong, nagsasabing,...  Negative    0.492186
# 2301  [took, blind, test, top, candidates, hahaha, g...   Neutral    0.714857
# 2303  [abc, news, young, ones, know, dictator's, dar...  Negative    0.771323
#
# [1440 rows x 4 columns]

# %%
groupedby_cnn_label = fastTextCNN_test_results.groupby(fastTextCNN_test_results.Label)
#group by label
cnn_positive = groupedby_cnn_label.get_group("Positive")
cnn_negative = groupedby_cnn_label.get_group("Negative")
cnn_neutral = groupedby_cnn_label.get_group("Neutral")

# %%
#get top keywords by tfidf

# %%
#fasttextcnn highest keywords positive
get_keywords(cnn_positive.Tokens.values,'fastTextCNN_positive_keywords.csv').head(20)
# Out:
# fastTextCNN_positive_keywords.csv
#                   Token  TFIDF_Value
# 0    aaaaaaaaaaaaaaaaaa     6.351858
# 933         napatunayan     6.351858
# 943          natulungan     6.351858
# 942              native     6.351858
# 941            national     6.351858
# 939          natin--ang     6.351858
# 937           nasusukat     6.351858
# 935             narinig     6.351858
# 934              narido     6.351858
# 932              nanjun     6.351858
# 945                  nb     6.351858
# 928     nangangailangan     6.351858
# 926             nandito     6.351858
# 925               nanay     6.351858
# 924         nananawagan     6.351858
# 921           namatagal     6.351858
# 919            naloloka     6.351858
# 917           nalalapit     6.351858
# 944                nawa     6.351858
# 946                 ncr     6.351858

# %%
#fasttextcnn highest keywords negative
get_keywords(cnn_negative.Tokens.values,'fastTextCNN_negative_keywords.csv').head(20)
# Out:
# fastTextCNN_negative_keywords.csv
#                Token  TFIDF_Value
# 1599       magrebutt     6.554896
# 1940  nangangampanya     6.554896
# 1912        nakikita     6.554896
# 1913        nakilala     6.554896
# 1914      nakinabang     6.554896
# 1916       nalalaman     6.554896
# 1917         nalaman     6.554896
# 1919      nalulutang     6.554896
# 1923       namatayan     6.554896
# 1924     nambabastos     6.554896
# 1926           namen     6.554896
# 1927        namesake     6.554896
# 1928       namumuhay     6.554896
# 1929          namuno     6.554896
# 1930         nanakaw     6.554896
# 1931       nanakawan     6.554896
# 1934        nananaig     6.554896
# 1936       nandidiri     6.554896
# 1937         nandito     6.554896
# 1911    nakikinabang     6.554896

# %%
#fasttextcnn highest keywords neutral
get_keywords(cnn_neutral.Tokens.values,'fastTextCNN_neutral_keywords.csv').head(20)
# Out:
# fastTextCNN_neutral_keywords.csv
#               Token  TFIDF_Value
# 0        Nationwide     6.529429
# 1459           okay     6.529429
# 1456             ok     6.529429
# 1455           ofws     6.529429
# 1450        offered     6.529429
# 1449          offer     6.529429
# 1448          odron     6.529429
# 1446           octa     6.529429
# 1445            oct     6.529429
# 1443       nutshell     6.529429
# 1439  nullification     6.529429
# 1438          nugon     6.529429
# 1437    notoriously     6.529429
# 1435     noticeably     6.529429
# 1433          noong     6.529429
# 1432       non-stop     6.529429
# 1431            nme     6.529429
# 1430          nkklk     6.529429
# 1429           niyo     6.529429
# 1428     niyabangan     6.529429

# %%
cnn_positive
# Out:
#                                                   Tweet  \
# 6     dios mabalos bicolandia miting avance puno say...
# 20    gobyernong tapat angat buhay siyempre ipapanal...
# 33    ncr kayo naman ipanalo bbmsara pula pilipinas ...
# 34    preferred president yes magpapasakop pamamahal...
# 37    darating nandito susuriin natin kandidato anga...
# ...                                                 ...
# 2280          wdym epitome transparency good governance
# 2284  gobyernong tapat angat buhay siyempre ipapanal...
# 2285  vote president republic philippines kabayan ta...
# 2289                     manifesting president cutieeee
# 2295                          best job woman love madam
#
#                                                  Tokens     Label  Prediction
# 6     [dios, mabalos, bicolandia, miting, avance, pu...  Positive    0.604293
# 20    [gobyernong, tapat, angat, buhay, siyempre, ip...  Positive    0.923985
# 33    [ncr, kayo, naman, ipanalo, bbmsara, pula, pil...  Positive    0.740116
# 34    [preferred, president, yes, magpapasakop, pama...  Positive    0.531071
# 37    [darating, nandito, susuriin, natin, kandidato...  Positive    0.512630
# ...                                                 ...       ...         ...
# 2280    [wdym, epitome, transparency, good, governance]  Positive    0.678835
# 2284  [gobyernong, tapat, angat, buhay, siyempre, ip...  Positive    0.882918
# 2285  [vote, president, republic, philippines, kabay...  Positive    0.526141
# 2289                 [manifesting, president, cutieeee]  Positive    0.533067
# 2295                    [best, job, woman, love, madam]  Positive    0.835001
#
# [421 rows x 4 columns]

# %%
#top cnn positive sentences sorted by prediction
cnn_positive_sortedbyprediction = cnn_positive.sort_values(by=['Prediction'], ascending=False)
cnn_positive_sortedbyprediction.to_csv('fastTextCNN_positive_results.csv', index=False)
cnn_positive_sortedbyprediction
# Out:
#                                                   Tweet  \
# 1766  gobyernong tapat angat buhay si reynaldo sang ...
# 2142  gobyernong tapat angat buhay si fritz certifie...
# 61    gobyernong tapat angat buhay si joshua asmod p...
# 2027  gobyernong tapat angat buhay si jessica studen...
# 1469  gobyernong tapat angat buhay si ahmadz student...
# ...                                                 ...
# 1238  feel presidente natin si called volunteers wil...
# 135   kumalma kayo japet penas twitbon reached writi...
# 1146                                                win
# 967       basta boto taong kayang wakasan kurapsyon kay
# 1032  dami gastos volunteer lang kapalit tapat sinun...
#
#                                                  Tokens     Label  Prediction
# 1766  [gobyernong, tapat, angat, buhay, si, reynaldo...  Positive    0.977605
# 2142  [gobyernong, tapat, angat, buhay, si, fritz, c...  Positive    0.977463
# 61    [gobyernong, tapat, angat, buhay, si, joshua, ...  Positive    0.977406
# 2027  [gobyernong, tapat, angat, buhay, si, jessica,...  Positive    0.976477
# 1469  [gobyernong, tapat, angat, buhay, si, ahmadz, ...  Positive    0.975519
# ...                                                 ...       ...         ...
# 1238  [feel, presidente, natin, si, called, voluntee...  Positive    0.404844
# 135   [kumalma, kayo, japet, penas, twitbon, reached...  Positive    0.402474
# 1146                                              [win]  Positive    0.400403
# 967   [basta, boto, taong, kayang, wakasan, kurapsyo...  Positive    0.396248
# 1032  [dami, gastos, volunteer, lang, kapalit, tapat...  Positive    0.384368
#
# [421 rows x 4 columns]

# %%
cnn_negative
# Out:
#                                                   Tweet  \
# 1     kumalat text messages kandidatura malamang ant...
# 5         toxic pinklawan impluwensya fushiang ina niyo
# 12    there's lutang ballot might nuisance candidate...
# 14    pinklawan trolls address volunteers reports na...
# 19    consistency make credibility credible example ...
# ...                                                 ...
# 2286  looks like grandmother looks like mother heari...
# 2287  pala nabihisan basurero basura padin palang la...
# 2291  tanginang reference yan dot com ahhahahahahahahha
# 2296  nalang talaga nahihiya taong nagsasabing lutan...
# 2303  abc news young ones know dictator's dark past ...
#
#                                                  Tokens     Label  Prediction
# 1     [kumalat, text, messages, kandidatura, malaman...  Negative    0.922156
# 5     [toxic, pinklawan, impluwensya, fushiang, ina,...  Negative    0.938819
# 12    [there's, lutang, ballot, might, nuisance, can...  Negative    0.429331
# 14    [pinklawan, trolls, address, volunteers, repor...  Negative    0.510917
# 19    [consistency, make, credibility, credible, exa...  Negative    0.712286
# ...                                                 ...       ...         ...
# 2286  [looks, like, grandmother, looks, like, mother...  Negative    0.604325
# 2287  [pala, nabihisan, basurero, basura, padin, pal...  Negative    0.903266
# 2291  [tanginang, reference, yan, dot, com, ahhahaha...  Negative    0.899021
# 2296  [nalang, talaga, nahihiya, taong, nagsasabing,...  Negative    0.492186
# 2303  [abc, news, young, ones, know, dictator's, dar...  Negative    0.771323
#
# [516 rows x 4 columns]

# %%
#top cnn negative sentences sorted by prediction
cnn_negative_sortedbyprediction = cnn_negative.sort_values(by=['Prediction'], ascending=False)
cnn_negative_sortedbyprediction.to_csv('fastTextCNN_negative_results.csv', index=False)
cnn_negative_sortedbyprediction
# Out:
#                                                   Tweet  \
# 2015  kya nga ayaw attend debate mabibisto bobo bobo...
# 599   nagsasabing bobo si gago mas bobo kayo hahahah...
# 162   ba alam magnanakaw si ba alam komunista npa se...
# 23    panu masasabi magnanakaw eh mahirap mong presi...
# 2176  bobo daw si bobo lagay yan pano lang yung di i...
# ...                                                 ...
# 1084             apologist hahahaa yung hubby si friend
# 2093           choose choose toxic community supporters
# 1975  neither shining holding panelists he's eating ...
# 1877  nagtataka okay lang suportahan communist group...
# 401   naman malaki ngipin nya wala lang siyang gilag...
#
#                                                  Tokens     Label  Prediction
# 2015  [kya, nga, ayaw, attend, debate, mabibisto, bo...  Negative    0.999999
# 599   [nagsasabing, bobo, si, gago, mas, bobo, kayo,...  Negative    0.999977
# 162   [ba, alam, magnanakaw, si, ba, alam, komunista...  Negative    0.999876
# 23    [panu, masasabi, magnanakaw, eh, mahirap, mong...  Negative    0.999801
# 2176  [bobo, daw, si, bobo, lagay, yan, pano, lang, ...  Negative    0.999443
# ...                                                 ...       ...         ...
# 1084      [apologist, hahahaa, yung, hubby, si, friend]  Negative    0.371886
# 2093     [choose, choose, toxic, community, supporters]  Negative    0.367519
# 1975  [neither, shining, holding, panelists, he's, e...  Negative    0.350853
# 1877  [nagtataka, okay, lang, suportahan, communist,...  Negative    0.350743
# 401   [naman, malaki, ngipin, nya, wala, lang, siyan...  Negative    0.341851
#
# [516 rows x 4 columns]

# %%
cnn_neutral
# Out:
#                                                   Tweet  \
# 0     presidential candidate said would continue tra...
# 2     vp visits roxas city watch vp sen kiko pangili...
# 4     camp presidential frontrunner says endorsement...
# 16    kuya please po ayusin nyo po pag gawa stage ha...
# 17              hope win president monday wanna see cry
# ...                                                 ...
# 2269  presidente aadam bise presidente kiko pag ilig...
# 2276                                        mara cepeda
# 2279                                          president
# 2288                                    vp game changer
# 2301  took blind test top candidates hahaha gates na...
#
#                                                  Tokens    Label  Prediction
# 0     [presidential, candidate, said, would, continu...  Neutral    0.741291
# 2     [vp, visits, roxas, city, watch, vp, sen, kiko...  Neutral    0.811498
# 4     [camp, presidential, frontrunner, says, endors...  Neutral    0.766553
# 16    [kuya, please, po, ayusin, nyo, po, pag, gawa,...  Neutral    0.478939
# 17      [hope, win, president, monday, wanna, see, cry]  Neutral    0.479561
# ...                                                 ...      ...         ...
# 2269  [presidente, aadam, bise, presidente, kiko, pa...  Neutral    0.595427
# 2276                                     [mara, cepeda]  Neutral    0.452944
# 2279                                        [president]  Neutral    0.623543
# 2288                                [vp, game, changer]  Neutral    0.574352
# 2301  [took, blind, test, top, candidates, hahaha, g...  Neutral    0.714857
#
# [503 rows x 4 columns]

# %%
#top cnn neutral sentences sorted by prediction
cnn_neutral_sortedbyprediction = cnn_neutral.sort_values(by=['Prediction'], ascending=False)
cnn_neutral_sortedbyprediction.to_csv('fastTextCNN_neutral_results.csv', index=False)
cnn_neutral_sortedbyprediction
# Out:
#                                                   Tweet  \
# 486                            photo grabbed vp fb page
# 2019  look dating sen nakikipagpulong kaniyang team ...
# 1626  sinusuyod presidential candidate vice pres min...
# 25    halalan hundreds catholic leaders endorse pres...
# 2097  dumalo ngayong hapon sina sen sen tito sotto s...
# ...                                                 ...
# 1587
# 1275
# 495                                        miguel odron
# 311   us ward bigla biglang sumisigaw chant presiden...
# 452   tahol lang kayo niyo mababago isip tao lalong ...
#
#                                                  Tokens    Label  Prediction
# 486                      [photo, grabbed, vp, fb, page]  Neutral    0.970600
# 2019  [look, dating, sen, nakikipagpulong, kaniyang,...  Neutral    0.949600
# 1626  [sinusuyod, presidential, candidate, vice, pre...  Neutral    0.936811
# 25    [halalan, hundreds, catholic, leaders, endorse...  Neutral    0.936087
# 2097  [dumalo, ngayong, hapon, sina, sen, sen, tito,...  Neutral    0.932440
# ...                                                 ...      ...         ...
# 1587                                                 []  Neutral    0.373143
# 1275                                                 []  Neutral    0.373143
# 495                                     [miguel, odron]  Neutral    0.373143
# 311   [us, ward, bigla, biglang, sumisigaw, chant, p...  Neutral    0.364189
# 452   [tahol, lang, kayo, niyo, mababago, isip, tao,...  Neutral    0.345402
#
# [503 rows x 4 columns]
