# %%
#import necessary libraries
import pandas as pd
import csv
import re
import validators
import emoji
import unidecode
import nltk
import pickle
nltk.download('stopwords')
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.tokenize import WhitespaceTokenizer
from itertools import chain
import time
from sklearn.feature_extraction.text import TfidfVectorizer
import keras
from keras.preprocessing import sequence
import tensorflow as tf
from keras import Input
from keras import optimizers
from keras import backend as K
import torch
from keras import regularizers
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_blobs
from keras.models import Sequential
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib import pyplot
from keras.models import load_model
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectPercentile, f_classif

import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D 
from keras.utils import np_utils
from keras.utils import plot_model
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from itertools import chain

from tqdm import tqdm
from gensim.models import fasttext
from gensim.test.utils import datapath
import os, re, csv, math, codecs, pickle, nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kirby
# [nltk_data]     Wenceslao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Load test and testresutls   

with open('x_test.pkl', 'rb') as file:
    x_test = pickle.load(file)
    
with open('y_test.pkl', 'rb') as file:
    y_test = pickle.load(file)
    
with open('fastTextCNN_test_results.pkl', 'rb') as file:
    fastTextCNN_test_results = pickle.load(file) 
    
with open('TFIDFFFNN_test_results.pkl', 'rb') as file:
    TFIDFFFNN_test_results = pickle.load(file)  
    
#Convert Labels from Strings to categorical Integers {Non-Hate = 1, Hate = 0}


df_ytest = pd.DataFrame(y_test, columns = ['Label'])

fastTextCNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

fastTextCNN_tweets_joined = []

for i in range(len(fastTextCNN_test_results.Tokens.values)):
    tweet = " ".join(fastTextCNN_test_results.Tokens.values[i])
    fastTextCNN_tweets_joined.append(tweet)
    
fastTextCNN_test_results.insert(0, "Tweet", fastTextCNN_tweets_joined, True)


TFIDFFFNN_test_results.columns = ['Tokens', 'Label', 'Prediction']

tfidfffnn_tweets_joined = []
for i in range(len(TFIDFFFNN_test_results.Tokens.values)):
    tweet = " ".join(TFIDFFFNN_test_results.Tokens.values[i])
    tfidfffnn_tweets_joined.append(tweet)
    
TFIDFFFNN_test_results.insert(0, "Tweet", tfidfffnn_tweets_joined, True)
#TFIDFFFNN_test_results['Label'] = TFIDFFFNN_test_results['Label'].str.get(0)
#TFIDFFFNN_test_results['Prediction'] = TFIDFFFNN_test_results['Prediction'].str.get(0)
#flatten training set for fitting on tfidf
#x_train_fit = list(chain.from_iterable(x_train))

mapping = {'Positive': 0, 'Negative': 1, 'Neutral':2}
mapping_reverse = {0:'Positive', 1: 'Negative', 2: 'Neutral'}
fastTextCNN_test_results = fastTextCNN_test_results.replace({'Label': mapping_reverse})
TFIDFFFNN_test_results = TFIDFFFNN_test_results.replace({'Label': mapping_reverse})
df_ytest = df_ytest.replace({'Label': mapping})

# %%
#collect index of misclassified and remove from results


fasttext_misclassified = []
tfidf_misclassified = []

for i in range(len(y_test)):
    if(y_test[i] != fastTextCNN_test_results.Label.values[i]):
        fasttext_misclassified.append(i)
        
    if(y_test[i] != TFIDFFFNN_test_results.Label.values[i]):
        tfidf_misclassified.append(i)
    
print(len(fasttext_misclassified))
print(len(tfidf_misclassified))

#remove misclassified
fastTextCNN_test_results.drop(fasttext_misclassified, inplace = True )
TFIDFFFNN_test_results.drop(tfidf_misclassified, inplace = True )

print()
# Out:
# 551
# 556

# %%
fastTextCNN_test_results.shape
# Out:
# (985, 4)

# %%
TFIDFFFNN_test_results.shape
# Out:
# (980, 4)

# %%
TFIDFFFNN_test_results
# Out:
#                                                   Tweet  \
# 1                     yes future president lang sakalam
# 2     malaking insulto mamamayan kampanyador volunte...
# 4     gobyernong tapat angat buhay si sab nakiki-isa...
# 5     saludo po sa'yo madam tapat mabuti po lagi nam...
# 7                           nuisance candidate lang ata
# ...                                                 ...
# 1526
# 1527  talking country's relationship united states k...
# 1528  ba naman itong ayaw ayaw martial law tapos pur...
# 1530  h2h lagi pag bata chant yan tyak bbm past days...
# 1532  days nalang bakla palam kayo advance nyo loser...
#
#                                                  Tokens     Label  Prediction
# 1               [yes, future, president, lang, sakalam]  Positive    0.862531
# 2     [malaking, insulto, mamamayan, kampanyador, vo...   Neutral    0.988202
# 4     [gobyernong, tapat, angat, buhay, si, sab, nak...  Positive    0.999698
# 5     [saludo, po, sa'yo, madam, tapat, mabuti, po, ...  Positive    0.545739
# 7                      [nuisance, candidate, lang, ata]  Negative    0.967991
# ...                                                 ...       ...         ...
# 1526                                                 []  Positive    0.393490
# 1527  [talking, country's, relationship, united, sta...   Neutral    0.848311
# 1528  [ba, naman, itong, ayaw, ayaw, martial, law, t...  Negative    0.999995
# 1530  [h2h, lagi, pag, bata, chant, yan, tyak, bbm, ...  Positive    0.777785
# 1532  [days, nalang, bakla, palam, kayo, advance, ny...  Negative    0.999983
#
# [980 rows x 4 columns]

# %%
TFIDFFFNN_test_results.shape
# Out:
# (980, 4)

# %%
print(len(df_ytest))
# Out:
# 1536

# %%
def dummy_fun(doc):
    return doc

def get_keywords(data,filename):
    print(filename)
    tfidf = TfidfVectorizer(
        analyzer='word',
        tokenizer=dummy_fun,
        preprocessor=dummy_fun,
        token_pattern=None)  

    #fit text to tfidf
    tfidf.fit_transform(data)


    fasttext_dict = list(zip(tfidf.get_feature_names(), tfidf.idf_))
    fasttext_df = pd.DataFrame(fasttext_dict, columns = ['Token', 'TFIDF_Value'])
    fasttextresults_label_sorted = fasttext_df.sort_values(by=['TFIDF_Value'], ascending=False)
    fasttextresults_label_sorted.to_csv(filename, index=False)
    
    return fasttextresults_label_sorted

# %%
TFIDFFFNN_test_results.to_csv('TFIDFFFNN_test_results.csv', index=False)
TFIDFFFNN_test_results
# Out:
#                                                   Tweet  \
# 1                     yes future president lang sakalam
# 2     malaking insulto mamamayan kampanyador volunte...
# 4     gobyernong tapat angat buhay si sab nakiki-isa...
# 5     saludo po sa'yo madam tapat mabuti po lagi nam...
# 7                           nuisance candidate lang ata
# ...                                                 ...
# 1526
# 1527  talking country's relationship united states k...
# 1528  ba naman itong ayaw ayaw martial law tapos pur...
# 1530  h2h lagi pag bata chant yan tyak bbm past days...
# 1532  days nalang bakla palam kayo advance nyo loser...
#
#                                                  Tokens     Label  Prediction
# 1               [yes, future, president, lang, sakalam]  Positive    0.862531
# 2     [malaking, insulto, mamamayan, kampanyador, vo...   Neutral    0.988202
# 4     [gobyernong, tapat, angat, buhay, si, sab, nak...  Positive    0.999698
# 5     [saludo, po, sa'yo, madam, tapat, mabuti, po, ...  Positive    0.545739
# 7                      [nuisance, candidate, lang, ata]  Negative    0.967991
# ...                                                 ...       ...         ...
# 1526                                                 []  Positive    0.393490
# 1527  [talking, country's, relationship, united, sta...   Neutral    0.848311
# 1528  [ba, naman, itong, ayaw, ayaw, martial, law, t...  Negative    0.999995
# 1530  [h2h, lagi, pag, bata, chant, yan, tyak, bbm, ...  Positive    0.777785
# 1532  [days, nalang, bakla, palam, kayo, advance, ny...  Negative    0.999983
#
# [980 rows x 4 columns]

# %%
groupedby_ffnn_label = TFIDFFFNN_test_results.groupby(TFIDFFFNN_test_results.Label)

#group by label
ffnn_positive = groupedby_ffnn_label.get_group("Positive")
ffnn_negative = groupedby_ffnn_label.get_group("Negative")
ffnn_neutral = groupedby_ffnn_label.get_group("Neutral")

# %%
#tfidf highest keywords ffnn positive
get_keywords(ffnn_positive.Tokens.values,'TFIDFFFNN_positive_keywords.csv').head(20)
# Out:
# TFIDFFFNN_positive_keywords.csv
#             Token  TFIDF_Value
# 0           aagos     6.053056
# 744  napakababang     6.053056
# 748      nasabing     6.053056
# 749       natasha     6.053056
# 752        nation     6.053056
# 753      nation's     6.053056
# 754    natulungan     6.053056
# 755          neck     6.053056
# 756          need     6.053056
# 758       negosyo     6.053056
# 759         never     6.053056
# 761          news     6.053056
# 764        ngalan     6.053056
# 766        nicdao     6.053056
# 768        nicole     6.053056
# 769         night     6.053056
# 770          nina     6.053056
# 772       ninyong     6.053056
# 773        nitong     6.053056
# 775           non     6.053056

# %%
#tfidf highest keywords ffnn negative
get_keywords(ffnn_negative.Tokens.values,'TFIDFFFNN_negative_keywords.csv').head(20)
# Out:
# TFIDFFFNN_negative_keywords.csv
#              Token  TFIDF_Value
# 0            aaral     6.260096
# 1556     nirecount     6.260096
# 1549      nilalang     6.260096
# 1548   nilalabanan     6.260096
# 1547       nilagay     6.260096
# 1546  nila?...kaya     6.260096
# 1544      nickname     6.260096
# 1542        ngipin     6.260096
# 1541        ngayun     6.260096
# 1539         ngaun     6.260096
# 1538         ngang     6.260096
# 1537          ngaa     6.260096
# 1530        netong     6.260096
# 1529           net     6.260096
# 1528        nerved     6.260096
# 1527          neri     6.260096
# 1526        nenega     6.260096
# 1525     neighbors     6.260096
# 1524    negativity     6.260096
# 1521         nazis     6.260096

# %%
#tfidf highest keywords ffnn negative
get_keywords(ffnn_neutral.Tokens.values,'TFIDFFFNN_neutral_keywords.csv').head(20)
# Out:
# TFIDFFFNN_neutral_keywords.csv
#                   Token  TFIDF_Value
# 0                    My     5.959342
# 887  non-administration     5.959342
# 897           nutrisyon     5.959342
# 895             numbers     5.959342
# 893               nugon     5.959342
# 892           ntf-elcac     5.959342
# 891               norte     5.959342
# 889       non-surprises     5.959342
# 888        non-surprise     5.959342
# 885             nilinaw     5.959342
# 923                page     5.959342
# 884               nikko     5.959342
# 883             night's     5.959342
# 881                ngaa     5.959342
# 880                 nga     5.959342
# 877            newfound     5.959342
# 876                 new     5.959342
# 874             neutral     5.959342
# 898            obtained     5.959342
# 899          occidental     5.959342

# %%
#positive
ffnn_positive
# Out:
#                                                   Tweet  \
# 1                     yes future president lang sakalam
# 4     gobyernong tapat angat buhay si sab nakiki-isa...
# 5     saludo po sa'yo madam tapat mabuti po lagi nam...
# 9                      sigurado iboto alamin si si kiko
# 13    excited nako pa-sona susunod pangulo republika...
# ...                                                 ...
# 1520  lpph boto kay girl almighty kasama stand pilip...
# 1521  sigurado panalo vp majority pilipino eh matata...
# 1523                       mahalaga boto naman boto kay
# 1526
# 1530  h2h lagi pag bata chant yan tyak bbm past days...
#
#                                                  Tokens     Label  Prediction
# 1               [yes, future, president, lang, sakalam]  Positive    0.862531
# 4     [gobyernong, tapat, angat, buhay, si, sab, nak...  Positive    0.999698
# 5     [saludo, po, sa'yo, madam, tapat, mabuti, po, ...  Positive    0.545739
# 9               [sigurado, iboto, alamin, si, si, kiko]  Positive    0.853484
# 13    [excited, nako, pa-sona, susunod, pangulo, rep...  Positive    0.914841
# ...                                                 ...       ...         ...
# 1520  [lpph, boto, kay, girl, almighty, kasama, stan...  Positive    0.999957
# 1521  [sigurado, panalo, vp, majority, pilipino, eh,...  Positive    0.963500
# 1523                 [mahalaga, boto, naman, boto, kay]  Positive    0.520121
# 1526                                                 []  Positive    0.393490
# 1530  [h2h, lagi, pag, bata, chant, yan, tyak, bbm, ...  Positive    0.777785
#
# [312 rows x 4 columns]

# %%
#top ffnn hate sentences sorted by prediction
ffnn_positive_sortedbyprediction = ffnn_positive.sort_values(by=['Prediction'], ascending=False)
ffnn_positive_sortedbyprediction.to_csv('TFIDFFFNN_positive_results.csv', index=False)
ffnn_positive_sortedbyprediction
# Out:
#                                                   Tweet  \
# 373   gobyernong tapat angat buhay si zia carat naki...
# 1016  gobyernong tapat angat buhay si celina former ...
# 691   si christian engineering student nakiki-isa pa...
# 652   talaga natin tunay pagbabago kakayahan puso pa...
# 1319  talaga natin tunay pagbabago kakayahan puso pa...
# ...                                                 ...
# 1072                                            alright
# 451                               yassification moments
# 913                                  like..but presdint
# 1526
# 1191                  yassified freshident mamshie purr
#
#                                                  Tokens     Label  Prediction
# 373   [gobyernong, tapat, angat, buhay, si, zia, car...  Positive    0.999998
# 1016  [gobyernong, tapat, angat, buhay, si, celina, ...  Positive    0.999996
# 691   [si, christian, engineering, student, nakiki-i...  Positive    0.999990
# 652   [talaga, natin, tunay, pagbabago, kakayahan, p...  Positive    0.999990
# 1319  [talaga, natin, tunay, pagbabago, kakayahan, p...  Positive    0.999990
# ...                                                 ...       ...         ...
# 1072                                          [alright]  Positive    0.393490
# 451                            [yassification, moments]  Positive    0.393490
# 913                               [like..but, presdint]  Positive    0.393490
# 1526                                                 []  Positive    0.393490
# 1191             [yassified, freshident, mamshie, purr]  Positive    0.393490
#
# [312 rows x 4 columns]

# %%
#for negative
ffnn_negative
# Out:
#                                                   Tweet  \
# 7                           nuisance candidate lang ata
# 8     high time descends upon bobong play little smn...
# 19     jusko lang kayo maawa kayo dignidad nyo loyalist
# 25    fact part pork barrel scam lacks educational a...
# 29    resibo always high drugs nikki coseteng former...
# ...                                                 ...
# 1518                                  president satanas
# 1519  sure tatahol naman tong bbm supporters naman m...
# 1525  kasus linis linis kala bahid karumihan yung po...
# 1528  ba naman itong ayaw ayaw martial law tapos pur...
# 1532  days nalang bakla palam kayo advance nyo loser...
#
#                                                  Tokens     Label  Prediction
# 7                      [nuisance, candidate, lang, ata]  Negative    0.967991
# 8     [high, time, descends, upon, bobong, play, lit...  Negative    0.986892
# 19    [jusko, lang, kayo, maawa, kayo, dignidad, nyo...  Negative    0.970395
# 25    [fact, part, pork, barrel, scam, lacks, educat...  Negative    0.999632
# 29    [resibo, always, high, drugs, nikki, coseteng,...  Negative    0.998802
# ...                                                 ...       ...         ...
# 1518                               [president, satanas]  Negative    0.998356
# 1519  [sure, tatahol, naman, tong, bbm, supporters, ...  Negative    0.996591
# 1525  [kasus, linis, linis, kala, bahid, karumihan, ...  Negative    0.524460
# 1528  [ba, naman, itong, ayaw, ayaw, martial, law, t...  Negative    0.999995
# 1532  [days, nalang, bakla, palam, kayo, advance, ny...  Negative    0.999983
#
# [384 rows x 4 columns]

# %%
#top ffnn negative sentences sorted by prediction
ffnn_negative_sortedbyprediction = ffnn_negative.sort_values(by=['Prediction'], ascending=False)
ffnn_negative_sortedbyprediction.to_csv('TFIDFFFNN_negative_results.csv', index=False)
ffnn_negative_sortedbyprediction
# Out:
#                                                   Tweet  \
# 832   philippines presidential frontrunner using tik...
# 186   stupid kakampinks tolerating another stupid pi...
# 496   philippines presidential frontrunner using tik...
# 634   philippines presidential frontrunner using tik...
# 333   smni debates matter nice debate biased shunga ...
# ...                                                 ...
# 321   nanalo si vp niloko tinraydor gaya naunang adm...
# 925               pinanganak manatiling talunan periodt
# 356   po naniniwala deadlines tangina bagong motivat...
# 1476                        mabuti nalng acceptable kay
# 865   usually research turns worst vice president ph...
#
#                                                  Tokens     Label  Prediction
# 832   [philippines, presidential, frontrunner, using...  Negative    1.000000
# 186   [stupid, kakampinks, tolerating, another, stup...  Negative    1.000000
# 496   [philippines, presidential, frontrunner, using...  Negative    1.000000
# 634   [philippines, presidential, frontrunner, using...  Negative    1.000000
# 333   [smni, debates, matter, nice, debate, biased, ...  Negative    1.000000
# ...                                                 ...       ...         ...
# 321   [nanalo, si, vp, niloko, tinraydor, gaya, naun...  Negative    0.508970
# 925          [pinanganak, manatiling, talunan, periodt]  Negative    0.495190
# 356   [po, naniniwala, deadlines, tangina, bagong, m...  Negative    0.477548
# 1476                   [mabuti, nalng, acceptable, kay]  Negative    0.453421
# 865   [usually, research, turns, worst, vice, presid...  Negative    0.419889
#
# [384 rows x 4 columns]

# %%
#for neutral
ffnn_neutral
# Out:
#                                                   Tweet  \
# 2     malaking insulto mamamayan kampanyador volunte...
# 10            dr entertainment purposes i've good laugh
# 17                                            president
# 21                             th president philippines
# 26    maria leonor gerona th president republic phil...
# ...                                                 ...
# 1492              president sara duterte vice president
# 1499                made clear next president ferdinand
# 1500  liberal party chair vp explains seeking presid...
# 1517  sincere wisest ernesto patriotic experienced s...
# 1527  talking country's relationship united states k...
#
#                                                  Tokens    Label  Prediction
# 2     [malaking, insulto, mamamayan, kampanyador, vo...  Neutral    0.988202
# 10     [dr, entertainment, purposes, i've, good, laugh]  Neutral    0.956122
# 17                                          [president]  Neutral    0.704675
# 21                         [th, president, philippines]  Neutral    0.646918
# 26    [maria, leonor, gerona, th, president, republi...  Neutral    0.927547
# ...                                                 ...      ...         ...
# 1492        [president, sara, duterte, vice, president]  Neutral    0.526866
# 1499          [made, clear, next, president, ferdinand]  Neutral    0.907380
# 1500  [liberal, party, chair, vp, explains, seeking,...  Neutral    0.999877
# 1517  [sincere, wisest, ernesto, patriotic, experien...  Neutral    0.980926
# 1527  [talking, country's, relationship, united, sta...  Neutral    0.848311
#
# [284 rows x 4 columns]

# %%
#top ffnn neutral sentences sorted by prediction
ffnn_neutral_sortedbyprediction = ffnn_neutral.sort_values(by=['Prediction'], ascending=False)
ffnn_neutral_sortedbyprediction.to_csv('TFIDFFFNN_neutral_results.csv', index=False)
ffnn_neutral_sortedbyprediction
# Out:
#                                                   Tweet  \
# 1490  gathering massive crowds different sorties vic...
# 972                     reporter's review lian buan via
# 840   uniteam inday sara duterde ends campaign rally...
# 351   look pres'l aspirant delivers introductory spe...
# 786   pinol joins senate slate non-administration ca...
# ...                                                 ...
# 839   manifest president vice president kiko pangilinan
# 1002              parang masyadong nakapagsalita si sir
# 287                            claiming everything he's
# 842                            pilipinas papa kinikilig
# 115                pag nanalo si vp ewan lang president
#
#                                                  Tokens    Label  Prediction
# 1490  [gathering, massive, crowds, different, sortie...  Neutral    0.999995
# 972               [reporter's, review, lian, buan, via]  Neutral    0.999995
# 840   [uniteam, inday, sara, duterde, ends, campaign...  Neutral    0.999993
# 351   [look, pres'l, aspirant, delivers, introductor...  Neutral    0.999991
# 786   [pinol, joins, senate, slate, non-administrati...  Neutral    0.999986
# ...                                                 ...      ...         ...
# 839   [manifest, president, vice, president, kiko, p...  Neutral    0.486937
# 1002        [parang, masyadong, nakapagsalita, si, sir]  Neutral    0.445779
# 287                        [claiming, everything, he's]  Neutral    0.424130
# 842                        [pilipinas, papa, kinikilig]  Neutral    0.382217
# 115        [pag, nanalo, si, vp, ewan, lang, president]  Neutral    0.356714
#
# [284 rows x 4 columns]

# %%
#For fasttext results

# %%
fastTextCNN_test_results.to_csv('fastTextCNN_test_results.csv', index=False)
fastTextCNN_test_results
# Out:
#                                                   Tweet  \
# 1                     yes future president lang sakalam
# 4     gobyernong tapat angat buhay si sab nakiki-isa...
# 5     saludo po sa'yo madam tapat mabuti po lagi nam...
# 6     labor leader closing statement says enough cha...
# 8     high time descends upon bobong play little smn...
# ...                                                 ...
# 1529  sorry jaime lopez principal author ra regardin...
# 1530  h2h lagi pag bata chant yan tyak bbm past days...
# 1532  days nalang bakla palam kayo advance nyo loser...
# 1533  next major ayuda bet sana donbelle president v...
# 1534            letter means president asan nga ba yung
#
#                                                  Tokens     Label  Prediction
# 1               [yes, future, president, lang, sakalam]  Positive    0.552971
# 4     [gobyernong, tapat, angat, buhay, si, sab, nak...  Positive    0.984135
# 5     [saludo, po, sa'yo, madam, tapat, mabuti, po, ...  Positive    0.706160
# 6     [labor, leader, closing, statement, says, enou...   Neutral    0.511017
# 8     [high, time, descends, upon, bobong, play, lit...  Negative    0.992185
# ...                                                 ...       ...         ...
# 1529  [sorry, jaime, lopez, principal, author, ra, r...   Neutral    0.538899
# 1530  [h2h, lagi, pag, bata, chant, yan, tyak, bbm, ...  Positive    0.438564
# 1532  [days, nalang, bakla, palam, kayo, advance, ny...  Negative    0.993325
# 1533  [next, major, ayuda, bet, sana, donbelle, pres...  Positive    0.484497
# 1534    [letter, means, president, asan, nga, ba, yung]  Negative    0.527408
#
# [985 rows x 4 columns]

# %%
groupedby_cnn_label = fastTextCNN_test_results.groupby(fastTextCNN_test_results.Label)
#group by label
cnn_positive = groupedby_cnn_label.get_group("Positive")
cnn_negative = groupedby_cnn_label.get_group("Negative")
cnn_neutral = groupedby_cnn_label.get_group("Neutral")

# %%
#get top keywords by tfidf

# %%
#fasttextcnn highest keywords positive
get_keywords(cnn_positive.Tokens.values,'fastTextCNN_positive_keywords.csv').head(20)
# Out:
# fastTextCNN_positive_keywords.csv
#              Token  TFIDF_Value
# 0            aagos     6.087596
# 694      malasakit     6.087596
# 696           mama     6.087596
# 697        mamahal     6.087596
# 1191        strong     6.087596
# 699         mamaya     6.087596
# 1189    strategies     6.087596
# 1188   storybrooke     6.087596
# 703          manda     6.087596
# 704        mandate     6.087596
# 705        mandsci     6.087596
# 706   manggagawang     6.087596
# 1187         story     6.087596
# 708     manindigan     6.087596
# 709          manok     6.087596
# 710      manunulat     6.087596
# 1186       stopped     6.087596
# 1185          stop     6.087596
# 713         marian     6.087596
# 714          mario     6.087596

# %%
#fasttextcnn highest keywords negative
get_keywords(cnn_negative.Tokens.values,'fastTextCNN_negative_keywords.csv').head(20)
# Out:
# fastTextCNN_negative_keywords.csv
#            Token  TFIDF_Value
# 0          aaral      6.17615
# 1462   narrative      6.17615
# 1482   neighbors      6.17615
# 1481  negativity      6.17615
# 1478         ndf      6.17615
# 1477       nazis      6.17615
# 1475     naunang      6.17615
# 1474     natural      6.17615
# 1473      native      6.17615
# 1472      nation      6.17615
# 1471      nating      6.17615
# 1469  natatamaan      6.17615
# 1468   natatakot      6.17615
# 1465       nasan      6.17615
# 1464    nasabing      6.17615
# 1461     narinig      6.17615
# 1484        neri      6.17615
# 1460    nareport      6.17615
# 1459  naramdaman      6.17615
# 1458  napatalsik      6.17615

# %%
#fasttextcnn highest keywords neutral
get_keywords(cnn_neutral.Tokens.values,'fastTextCNN_neutral_keywords.csv').head(20)
# Out:
# fastTextCNN_neutral_keywords.csv
#                  Token  TFIDF_Value
# 0                   My     6.043425
# 823        maipapanalo     6.043425
# 830            makipag     6.043425
# 1387             stint     6.043425
# 1388              stop     6.043425
# 1389             stops     6.043425
# 826               maka     6.043425
# 825           majority     6.043425
# 1391         strategic     6.043425
# 822          maintains     6.043425
# 851           marcos's     6.043425
# 821             mainit     6.043425
# 820          mahihirap     6.043425
# 1392           streets     6.043425
# 818   magpalipat-lipat     6.043425
# 817           magiging     6.043425
# 816              magic     6.043425
# 815          magandang     6.043425
# 1386             still     6.043425
# 832          makontrol     6.043425

# %%
cnn_positive
# Out:
#                                                   Tweet  \
# 1                     yes future president lang sakalam
# 4     gobyernong tapat angat buhay si sab nakiki-isa...
# 5     saludo po sa'yo madam tapat mabuti po lagi nam...
# 9                      sigurado iboto alamin si si kiko
# 13    excited nako pa-sona susunod pangulo republika...
# ...                                                 ...
# 1520  lpph boto kay girl almighty kasama stand pilip...
# 1521  sigurado panalo vp majority pilipino eh matata...
# 1523                       mahalaga boto naman boto kay
# 1530  h2h lagi pag bata chant yan tyak bbm past days...
# 1533  next major ayuda bet sana donbelle president v...
#
#                                                  Tokens     Label  Prediction
# 1               [yes, future, president, lang, sakalam]  Positive    0.552971
# 4     [gobyernong, tapat, angat, buhay, si, sab, nak...  Positive    0.984135
# 5     [saludo, po, sa'yo, madam, tapat, mabuti, po, ...  Positive    0.706160
# 9               [sigurado, iboto, alamin, si, si, kiko]  Positive    0.642954
# 13    [excited, nako, pa-sona, susunod, pangulo, rep...  Positive    0.533009
# ...                                                 ...       ...         ...
# 1520  [lpph, boto, kay, girl, almighty, kasama, stan...  Positive    0.914349
# 1521  [sigurado, panalo, vp, majority, pilipino, eh,...  Positive    0.521148
# 1523                 [mahalaga, boto, naman, boto, kay]  Positive    0.701233
# 1530  [h2h, lagi, pag, bata, chant, yan, tyak, bbm, ...  Positive    0.438564
# 1533  [next, major, ayuda, bet, sana, donbelle, pres...  Positive    0.484497
#
# [323 rows x 4 columns]

# %%
#top cnn positive sentences sorted by prediction
cnn_positive_sortedbyprediction = cnn_positive.sort_values(by=['Prediction'], ascending=False)
cnn_positive_sortedbyprediction.to_csv('fastTextCNN_positive_results.csv', index=False)
cnn_positive_sortedbyprediction
# Out:
#                                                   Tweet  \
# 660   gobyernong tapat angat buhay si jennie kim sim...
# 465   gobyernong tapat angat buhay si eprel carat un...
# 678   gobyernong tapat angat buhay si jowen onate bo...
# 1042  gobyernong tapat angat buhay si astria santos ...
# 298   gobyernong tapat angat buhay si kaizen manunul...
# ...                                                 ...
# 856   iboto kandidatong pagkapangulo si vp mas radik...
# 703   camp vote change mind wins feel thebest bbm wi...
# 1301         people think fighting little know fighting
# 367                               sino-sino inc members
# 166                           si lang magaling matalino
#
#                                                  Tokens     Label  Prediction
# 660   [gobyernong, tapat, angat, buhay, si, jennie, ...  Positive    0.987298
# 465   [gobyernong, tapat, angat, buhay, si, eprel, c...  Positive    0.987046
# 678   [gobyernong, tapat, angat, buhay, si, jowen, o...  Positive    0.986124
# 1042  [gobyernong, tapat, angat, buhay, si, astria, ...  Positive    0.985630
# 298   [gobyernong, tapat, angat, buhay, si, kaizen, ...  Positive    0.985363
# ...                                                 ...       ...         ...
# 856   [iboto, kandidatong, pagkapangulo, si, vp, mas...  Positive    0.418534
# 703   [camp, vote, change, mind, wins, feel, thebest...  Positive    0.403630
# 1301  [people, think, fighting, little, know, fighting]  Positive    0.375942
# 367                           [sino-sino, inc, members]  Positive    0.373930
# 166                      [si, lang, magaling, matalino]  Positive    0.372772
#
# [323 rows x 4 columns]

# %%
cnn_negative
# Out:
#                                                   Tweet  \
# 8     high time descends upon bobong play little smn...
# 11    manalo si matigil paniniwala tao basta endorso...
# 19     jusko lang kayo maawa kayo dignidad nyo loyalist
# 22                          paggamit dahas mean pnp afp
# 25    fact part pork barrel scam lacks educational a...
# ...                                                 ...
# 1519  sure tatahol naman tong bbm supporters naman m...
# 1525  kasus linis linis kala bahid karumihan yung po...
# 1528  ba naman itong ayaw ayaw martial law tapos pur...
# 1532  days nalang bakla palam kayo advance nyo loser...
# 1534            letter means president asan nga ba yung
#
#                                                  Tokens     Label  Prediction
# 8     [high, time, descends, upon, bobong, play, lit...  Negative    0.992185
# 11    [manalo, si, matigil, paniniwala, tao, basta, ...  Negative    0.763032
# 19    [jusko, lang, kayo, maawa, kayo, dignidad, nyo...  Negative    0.893659
# 22                    [paggamit, dahas, mean, pnp, afp]  Negative    0.921761
# 25    [fact, part, pork, barrel, scam, lacks, educat...  Negative    0.922263
# ...                                                 ...       ...         ...
# 1519  [sure, tatahol, naman, tong, bbm, supporters, ...  Negative    0.388494
# 1525  [kasus, linis, linis, kala, bahid, karumihan, ...  Negative    0.944048
# 1528  [ba, naman, itong, ayaw, ayaw, martial, law, t...  Negative    0.994867
# 1532  [days, nalang, bakla, palam, kayo, advance, ny...  Negative    0.993325
# 1534    [letter, means, president, asan, nga, ba, yung]  Negative    0.527408
#
# [353 rows x 4 columns]

# %%
#top cnn negative sentences sorted by prediction
cnn_negative_sortedbyprediction = cnn_negative.sort_values(by=['Prediction'], ascending=False)
cnn_negative_sortedbyprediction.to_csv('fastTextCNN_negative_results.csv', index=False)
cnn_negative_sortedbyprediction
# Out:
#                                                   Tweet  \
# 1193  anong ikinagagalit is/ko color fuchsia bang pr...
# 589   ba alam magnanakaw si ba alam komunista npa se...
# 644   si tamad duwag tax evader sinungaling higit pa...
# 87    ibiboto sana kaso nalaman pala worst vp bansan...
# 46    adik pwedeng bigyan chance magpanibagong buhay...
# ...                                                 ...
# 1317  oh let educate troll red-tagger aired concerns...
# 217   hey massuggest ba kayong credible website maki...
# 1519  sure tatahol naman tong bbm supporters naman m...
# 371                           still blinded pet project
# 1169                                  omg nakakahiya si
#
#                                                  Tokens     Label  Prediction
# 1193  [anong, ikinagagalit, is/ko, color, fuchsia, b...  Negative    0.999989
# 589   [ba, alam, magnanakaw, si, ba, alam, komunista...  Negative    0.999957
# 644   [si, tamad, duwag, tax, evader, sinungaling, h...  Negative    0.999917
# 87    [ibiboto, sana, kaso, nalaman, pala, worst, vp...  Negative    0.999183
# 46    [adik, pwedeng, bigyan, chance, magpanibagong,...  Negative    0.999175
# ...                                                 ...       ...         ...
# 1317  [oh, let, educate, troll, red-tagger, aired, c...  Negative    0.390943
# 217   [hey, massuggest, ba, kayong, credible, websit...  Negative    0.390331
# 1519  [sure, tatahol, naman, tong, bbm, supporters, ...  Negative    0.388494
# 371                      [still, blinded, pet, project]  Negative    0.354827
# 1169                              [omg, nakakahiya, si]  Negative    0.347704
#
# [353 rows x 4 columns]

# %%
cnn_neutral
# Out:
#                                                   Tweet  \
# 6     labor leader closing statement says enough cha...
# 10            dr entertainment purposes i've good laugh
# 17                                            president
# 26    maria leonor gerona th president republic phil...
# 44    current members alumni pugad sayk officially s...
# ...                                                 ...
# 1496  i'm convincing family vote realized qualificat...
# 1500  liberal party chair vp explains seeking presid...
# 1505                                      sec president
# 1522                       ptv interview march ruel via
# 1529  sorry jaime lopez principal author ra regardin...
#
#                                                  Tokens    Label  Prediction
# 6     [labor, leader, closing, statement, says, enou...  Neutral    0.511017
# 10     [dr, entertainment, purposes, i've, good, laugh]  Neutral    0.383478
# 17                                          [president]  Neutral    0.676913
# 26    [maria, leonor, gerona, th, president, republi...  Neutral    0.559935
# 44    [current, members, alumni, pugad, sayk, offici...  Neutral    0.556306
# ...                                                 ...      ...         ...
# 1496  [i'm, convincing, family, vote, realized, qual...  Neutral    0.455844
# 1500  [liberal, party, chair, vp, explains, seeking,...  Neutral    0.554424
# 1505                                   [sec, president]  Neutral    0.528182
# 1522                 [ptv, interview, march, ruel, via]  Neutral    0.828644
# 1529  [sorry, jaime, lopez, principal, author, ra, r...  Neutral    0.538899
#
# [309 rows x 4 columns]

# %%
#top cnn neutral sentences sorted by prediction
cnn_neutral_sortedbyprediction = cnn_neutral.sort_values(by=['Prediction'], ascending=False)
cnn_neutral_sortedbyprediction.to_csv('fastTextCNN_neutral_results.csv', index=False)
cnn_neutral_sortedbyprediction
# Out:
#                                                   Tweet  \
# 171   look presidential bet ferdinand spokesperson a...
# 793   watch says decision run president difficult on...
# 1054              tv host vice ganda sings rosas vp via
# 1281  vice president senator kiko pangilinan set con...
# 1069  presidential bet vp says ph use arbitral victo...
# ...                                                 ...
# 10            dr entertainment purposes i've good laugh
# 1131  maka baby akong subscribers youtube try persua...
# 1136    duterte pilipinas ps mas naparami lang yung kay
# 1385  murag nagpabilin nalang jod rason nganong ivot...
# 337   alam yan kundi mangurakot utang loob maawa kay...
#
#                                                  Tokens    Label  Prediction
# 171   [look, presidential, bet, ferdinand, spokesper...  Neutral    0.919240
# 793   [watch, says, decision, run, president, diffic...  Neutral    0.877265
# 1054     [tv, host, vice, ganda, sings, rosas, vp, via]  Neutral    0.864466
# 1281  [vice, president, senator, kiko, pangilinan, s...  Neutral    0.847801
# 1069  [presidential, bet, vp, says, ph, use, arbitra...  Neutral    0.835727
# ...                                                 ...      ...         ...
# 10     [dr, entertainment, purposes, i've, good, laugh]  Neutral    0.383478
# 1131  [maka, baby, akong, subscribers, youtube, try,...  Neutral    0.378550
# 1136  [duterte, pilipinas, ps, mas, naparami, lang, ...  Neutral    0.372643
# 1385  [murag, nagpabilin, nalang, jod, rason, nganon...  Neutral    0.357672
# 337   [alam, yan, kundi, mangurakot, utang, loob, ma...  Neutral    0.348542
#
# [309 rows x 4 columns]
